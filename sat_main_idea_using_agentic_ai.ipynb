# %% [markdown]
# # SAT Words in Context question generation using Strands Agentic AI framework and OpenAI model
#
# ## Overview
#
# My first [attempt](https://github.com/PragyanR/GenAI_for_SAT_Prep) to create words in context type question using Llama 3B on A100 was a bit involved from a coding perspective. With the advent of Agentic AI, I was able to generate such questions under 50 lines of code and a prompt template.
#
# Strands Agentic AI framework made it very simple to try out the use case.
#
# Check out my site if you want to try out Words in Context questions that I generated: [Acesat.ai](https://www.acesat.ai/).

# %% [markdown]
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * gpt-4.1-mini access
#
# Install the requirement packages for Strands Agent

# %%
# installing pre-requisites
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: strands-agents-tools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: aiohttp>=3.12.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (3.12.15)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.12)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.12)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.36.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.36.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.0.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: litellm<2.0.0,>=1.73.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents[litellm]->-r requirements.txt (line 3)) (1.75.8)
# Requirement already satisfied: openai<1.100.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents[litellm]->-r requirements.txt (line 3)) (1.99.9)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.20.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (8.2.1)
# Requirement already satisfied: httpx>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: tokenizers in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.13.3)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: six<2,>=1.15 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: anyio>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: starlette>=0.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.47.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.34.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: sniffio in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (4.65.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.57b0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: packaging>=18.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: wcwidth in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: html5lib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (1.1)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (5.4.0)
# Requirement already satisfied: regex in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (2023.8.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.16.1)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.36.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: webencodings in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.1)
#
# [notice] A new release of pip is available: 23.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Importing dependency packages
#
# Import the dependency packages

# %%
import os
from strands import Agent, tool
from strands.models.litellm import LiteLLMModel
import json

# %% [markdown]
# ### Setting up OpenAI keys
#
# Setup the OpenAI API Keys

# %%
os.environ["OPENAI_API_KEY"] = "<Key Goes here>"

# %% [markdown]
# ### Setting up custom tools
#
# I created three tools for the agent to call:
#
# first, check_word_exists, a tool for the agent to check if a word was used to create a words in context question already.
#
# second, store_paragraph, a tool for the agent to call for storing the generated paragraph.
#
# third, store_answer_choices, a tool for the agent to call for storing the answer choices and the word definitions.

# %%
# Dictionary for storing SAT inference questions (keyed by genre)
para = {}

@tool
def check_genre_exists(genre: str):
    '''
    Check if this genre or a very similar one was used already.
    Args:
        genre: SAT passage genre
    '''
    return genre in para


@tool
def store_paragraph(genre: str, paragraph: str):
    '''
    Store inference paragraph
    Args:
        genre: SAT passage genre
        paragraph: paragraph ending with "because ____"
    '''
    para[genre] = {
        "genre": genre,
        "question": paragraph,
        "ans_choices": [],
        "ans_choices_with_explanation": {},
        "correct_answer": None
    }


@tool
def store_answer_choice(choice: str, explanation: str, genre: str):
    '''
    Store answer choices and explanations
    Args:
        choice: answer choice text
        explanation: brief justification
        genre: SAT passage genre
    '''
    if choice not in para[genre]["ans_choices"]:
        para[genre]["ans_choices"].append(choice)

    para[genre]["ans_choices_with_explanation"][choice] = explanation


@tool
def set_correct_answer(choice: str, genre: str):
    '''
    Store the correct inference answer
    Args:
        choice: correct answer choice
        genre: SAT passage genre
    '''
    para[genre]["correct_answer"] = choice

# %% [markdown]
# ### LLM model
#
# Agent will leverage `gpt-4.1-mini` using LiteLLM.

# %%
model = "gpt-4.1-mini"
litellm_model = LiteLLMModel(
    model_id=model, params={"max_tokens": 32000, "temperature": 0.7}
)

# %% [markdown]
# ### Generating Words in Context questions

# %%
# Prompt template for generating words in context question
prompt = '''
You are generating authentic SAT Main Idea/ Central Idea questions.
You MUST use the provided tools to store and validate content.

Rules (SAT Authenticity):
- Use an academic, neutral tone.
- The conclusion must be implied, not explicitly tated.
- There must be exactly ONE logically valid completion.
- Avoid opinions, exaggeration, or unsupported assumptions.

Process:
1) Create a unique random Genre for the text. It can range from History, to science, to archertecture, to art.
2) Use check_question_genre(Genre).
   - If it returns a genre similar to the one generated, generate a new genre and restart.
   - else continue
3) Write a 70–90 word paragraph about the genre. Dont simply explane about the genre but talk about a niche, nuanced aspect of it. It must end with a line break and "Which choice best describes the main idea of the text?".
   - Do NOT have a sentence summarizing the main idea.
   - The whole text should be used to understand the main idea in the text.
5) Use store_paragraph(Genre, paragraph).

Answer Choices:
6) Generate exactly four answer choices (A–D):
   - One correct answer explaining the main idea.
   - One tempting but unsupported answer choice
   - Two clearly incorrect answer choices
7) For each answer choice, call:
   store_answer_choice(choice, explanation)
   - Explanation must be one concise sentence justifying correctness or incorrectness.
8) Use set_correct_answer(correct_choice).

Output Rules:
- Do NOT reveal reasoning steps.
- Do NOT explain unless explicitly asked.
- Ensure no more than one answer is defensible; otherwise, regenerate.
'''
# Function for generating
def generate_question(prompt):
    system_prompt = "You are a simple agent that can generate a paragraph for a given word"
    agent = Agent(
        model=litellm_model,
        system_prompt=system_prompt,
        tools=[store_paragraph, store_answer_choice, check_genre_exists,set_correct_answer],
    )
    agent(prompt)

# %%
# Specify number of questions to be generated
question_count = 50
para = {}

for i in range(question_count):
    generate_question(prompt)

# Print generated genres (one per question)
for genre in para.keys():
    print(genre)
# Out:
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# Historical archaeology focuses on the study of cultures and societies with written records, often combining physical artifacts with historical documents to gain a fuller understanding. Unlike prehistoric archaeology, it benefits from corroborating texts that provide context to the material finds. However, the interpretation of these findings requires careful consideration of biases in written sources and the archaeological record itself. This interplay between tangible evidence and textual information shapes our understanding of past human behaviors.
# Which choice best describes the main idea of the text?
#
# A) Historical archaeology integrates both material artifacts and written records to better understand past cultures.
# B) Historical archaeology primarily relies on written records and disregards physical artifacts.
# C) Historical archaeology studies only prehistoric societies without written records.
# D) Historical archaeology only relies on physical artifacts to interpret the past.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# The study of bioluminescence in marine organisms reveals a fascinating adaptation that allows certain species to produce and emit light. This light production can serve various ecological functions, such as attracting prey, deterring predators, or facilitating communication among members of the same species. The biochemical processes involved often include luciferin and luciferase compounds, which interact in specialized cells to create visible light. These adaptations highlight the complexity of survival strategies in oceanic environments. Which choice best describes the main idea of the text?
#
# A) The paragraph explains the various ecological functions and biochemical mechanisms behind bioluminescence in marine organisms.
# B) The text discusses the migration patterns of marine species and their impact on ocean ecosystems.
# C) The paragraph describes the physical characteristics of marine habitats.
# D) The text outlines the historical discovery of marine biology as a scientific discipline.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Neoclassical Architecture
#
# Neoclassical architecture, emerging in the mid-18th century, draws heavily on the principles of classical antiquity, emphasizing simplicity and symmetry. A niche aspect of this style is the revival of Greek orders, particularly the Doric and Ionic, which were adapted to modern construction techniques of the time. This blend of ancient design with contemporary methods allowed architects to achieve grandeur without excessive ornamentation. The style also reflects Enlightenment ideals, where rationality and clarity were paramount. Which choice best describes the main idea of the text?
#
# A. Neoclassical architecture revives Greek architectural orders using modern building techniques to achieve simplicity and grandeur.
# B. Neoclassical architecture is characterized by its ornate decoration and complex structures.
# C. Neoclassical architecture originated in ancient Greece and was forgotten until the 20th century.
# D. Neoclassical architecture primarily focuses on Gothic elements and medieval designs.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# During the Renaissance, artists developed techniques such as chiaroscuro and linear perspective to enhance the realism of their paintings. These methods allowed for more accurate depictions of light and depth, which contributed to the vividness of the scenes portrayed. This shift in artistic approach marked a departure from the flatter, more symbolic representations of earlier periods, influencing how viewers engaged with visual narratives. Which choice best describes the main idea of the text?
#
# A. The Renaissance introduced new artistic techniques that improved the realism and depth of paintings.
# B. Renaissance artists primarily focused on religious symbolism in their work.
# C. Renaissance art was less detailed than earlier art forms.
# D. Artists in the Renaissance used abstract forms to convey emotion.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# The genre is Environmental Science.
#
# Paragraph:
# The study of microplastics in ocean ecosystems has revealed their pervasive presence even in remote marine environments. These tiny plastic particles often originate from larger debris that breaks down over time. Researchers have started focusing on the impact of microplastics on marine life, particularly filter feeders such as mussels and plankton. These organisms ingest microplastics, which can then bioaccumulate through the food chain, potentially affecting larger marine animals and humans. This area of study is crucial because it highlights the unseen consequences of plastic pollution on ocean health.
# Which choice best describes the main idea of the text?
#
# Answer Choices:
# A. Microplastics in oceans pose a significant threat to marine ecosystems by entering the food chain.
# B. Plastic pollution is only a problem in heavily populated coastal areas.
# C. Microplastics have no impact on marine organisms because they are too small to be ingested.
# D. Marine animals are unaffected by pollution due to their natural resilience.
#
# Correct Answer: A
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Medieval architecture is often recognized for its grand cathedrals and castles, but a less discussed aspect is the use of flying buttresses to support walls and allow for higher ceilings and larger windows. These structural innovations not only enhanced the aesthetic appeal but also improved the functionality of buildings by distributing weight more efficiently. Understanding this architectural technique reveals how engineering and artistry intertwined during this period. Which choice best describes the main idea of the text?
#
# A. The text explains how flying buttresses improved both the structural integrity and design of medieval buildings.
# B. The text describes the religious symbolism behind medieval cathedrals.
# C. The text outlines the political history of medieval castle construction.
# D. The text emphasizes the use of medieval architecture in modern city planning.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Quantum entanglement challenges classical notions of locality by suggesting that particles can instantaneously affect each other's states regardless of distance. This phenomenon, which Einstein famously referred to as "spooky action at a distance," has profound implications for the future of communication and computing technologies. Researchers continue to explore how entanglement can be harnessed in practical applications, such as quantum cryptography and quantum teleportation. Which choice best describes the main idea of the text?
#
# A. Quantum entanglement reveals non-local connections between particles that have potential applications in advanced technologies.
# B. Quantum entanglement disproves all classical physics theories about particle behavior.
# C. Quantum entanglement is a simple phenomenon easily explained by classical physics.
# D. Quantum entanglement is only a theoretical concept with no practical use.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# The study of ancient pottery reveals insights into the daily lives and trade practices of early civilizations. Pottery styles and materials often varied significantly between regions, reflecting local resources and cultural influences. The evolution of pottery techniques, from hand-building to wheel-throwing, marks technological advancements within societies. Additionally, the distribution of pottery shards can indicate ancient trade routes and interactions. Which choice best describes the main idea of the text?
#
# A) Ancient pottery provides valuable information about early human societies and their technological and trade developments.
# B) Ancient pottery was primarily used for decorative purposes in early civilizations.
# C) Pottery techniques remained unchanged throughout ancient history.
# D) Ancient pottery is only important for understanding artistic styles.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# In ancient architectural techniques, the use of interlocking stones without mortar exemplified both engineering ingenuity and aesthetic values. This method not only provided structural stability but also allowed buildings to withstand natural disasters like earthquakes. The precision required to craft these stones reflects advanced knowledge of geometry and material properties. Such construction methods highlight a sophisticated understanding of balance and durability, which ancient builders achieved through painstaking manual labor and skill.
# Which choice best describes the main idea of the text?
#
# A. Ancient builders used interlocking stones to create earthquake-resistant structures demonstrating advanced engineering skills.
# B. Ancient architecture was primarily focused on aesthetic beauty rather than functionality.
# C. Ancient builders lacked knowledge of geometry and used mortar extensively.
# D. Ancient architectural techniques were simple and required little skill.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# The use of corbel arches in ancient architecture represents a distinctive engineering method that predates the development of the true arch. Unlike the true arch, which distributes weight evenly through a keystone, corbel arches rely on overlapping stones that gradually extend toward the center. This approach was instrumental in creating larger interior spaces in early structures and illustrates an incremental step in architectural innovation. Which choice best describes the main idea of the text?
#
# A. The paragraph explains how corbel arches differ from true arches in ancient architecture.
# B. The paragraph details the aesthetic beauty of corbel arches in ancient buildings.
# C. The paragraph describes the use of modern materials in ancient architecture.
# D. The paragraph argues that corbel arches were less effective than true arches.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Impressionist Art
#
# Impressionist art, emerging in the late 19th century, revolutionized traditional painting by focusing on light and color over detail. Artists often painted en plein air to capture the fleeting effects of natural light. This approach challenged established artistic norms and emphasized perception rather than realism. The movement's emphasis on spontaneity and everyday scenes distinguished it from previous art styles. Which choice best describes the main idea of the text?
#
# A) Impressionist art primarily focuses on capturing the changing effects of light and color in natural settings.
# B) Impressionist art seeks to portray historical and mythological subjects in great detail.
# C) Impressionist artists strictly adhered to classical techniques and realistic depictions.
# D) Impressionist art exclusively uses dark colors to convey mood and emotion.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# During the Age of Exploration, mariners relied on a combination of celestial navigation and rudimentary maps to traverse vast oceans. One particularly nuanced aspect of this practice was the use of the astrolabe to measure the altitude of the sun or stars above the horizon, which helped sailors determine their latitude. Despite its importance, the astrolabe had limitations in accuracy and was often supplemented by dead reckoning. This blend of tools and techniques highlights the complexity of early maritime navigation.
# Which choice best describes the main idea of the text?
#
# A. The text explains how early sailors combined different tools to navigate the seas effectively.
# B. The text details the construction and design of the astrolabe.
# C. The text argues that celestial navigation was more accurate than dead reckoning.
# D. The text provides a biography of famous explorers from the Age of Exploration.
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Astrobiology explores the potential for life beyond Earth, focusing on extreme environments within our solar system where life might exist. Recent studies emphasize the icy moons of Jupiter and Saturn, such as Europa and Enceladus, which have subsurface oceans beneath their frozen crusts. These environments offer conditions similar to Earth's deep ocean hydrothermal vents, where life thrives without sunlight. Understanding these parallels guides the search for extraterrestrial life and informs future exploratory missions.
# Which choice best describes the main idea of the text?
#
# A. The main focus of astrobiology is the study of hydrothermal vents on Earth.
# B. Astrobiology investigates environments on icy moons that may support life, drawing parallels with Earth's extreme habitats.
# C. Astrobiology is primarily concerned with the geological features of Jupiter and Saturn.
# D. Astrobiology proves that life exists on Europa and Enceladus.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Medieval manuscript art often featured intricate illuminations that served purposes beyond decoration, such as conveying theological or philosophical concepts through symbolic imagery. Artists used specific colors and motifs to guide the reader’s understanding of sacred texts, creating a visual narrative that complemented the written word. These illuminations were not merely ornamental but functioned as educational tools in monastic communities. Which choice best describes the main idea of the text?
#
# A) Illuminations in medieval manuscripts primarily served decorative purposes.
# B) Medieval manuscript illuminations were a complex visual language that enhanced understanding of religious texts.
# C) The primary function of medieval manuscripts was to preserve historical events.
# D) Medieval manuscript art was mainly produced for wealthy patrons and had little educational use.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Medieval manuscript illumination involved intricate decoration of texts, often using gold leaf and vivid colors to enhance religious and literary works. Artists in monasteries developed distinct regional styles that reflected local traditions and spiritual themes. These illuminations served not only as embellishments but also as visual guides to the text’s meaning and importance. The labor-intensive process required collaboration between scribes and illuminators, who balanced artistry with textual clarity.
# Which choice best describes the main idea of the text?
#
# A. The passage explains the collaboration and artistic techniques used in medieval manuscript illumination.
# B. The passage describes the historical timeline of medieval manuscripts.
# C. The passage argues that medieval manuscript illumination was primarily for aesthetic purposes.
# D. The passage focuses on the development of printing technology in medieval times.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Astrophysics
#
# Astrophysics often focuses on the study of celestial phenomena, but the behavior of neutron stars presents a particularly intriguing niche. These remnants of massive stars exhibit extreme densities and magnetic fields, creating conditions that challenge our understanding of physics. Observing their spin rates and emitted radiation patterns reveals insights into matter under intense pressure. Studying neutron stars helps scientists explore fundamental forces in the universe, which are otherwise inaccessible in terrestrial laboratories.
# Which choice best describes the main idea of the text?
#
# A. The text explains how neutron stars provide unique insights into extreme physical conditions in the universe.
# B. The text describes the general characteristics of all celestial bodies in space.
# C. The text argues that neutron stars are the most important objects in astrophysics.
# D. The text details the history of astrophysics as a scientific field.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
# I will generate a new unique genre and retry.
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Ancient Maritime Archaeology
#
# Ancient maritime archaeology focuses on the study of shipwrecks and submerged ports to uncover historical trade routes and cultural exchanges. Unlike terrestrial archaeology, it requires specialized underwater excavation techniques and technology to preserve fragile artifacts. The discipline has revealed insights into ancient economies and navigation methods, but challenges such as site accessibility and conservation remain significant. These factors shape how researchers interpret the maritime past. Which choice best describes the main idea of the text?
#
# A) Ancient maritime archaeology primarily involves studying underwater shipwrecks and ports to understand historical trade and navigation.
# B) Ancient maritime archaeology mainly deals with preserving modern boats to prevent decay.
# C) Ancient maritime archaeology is solely concerned with finding treasure from shipwrecks.
# D) Ancient maritime archaeology studies only the construction techniques of ancient ships.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Marine biology often focuses on vast ecosystems, but the study of bioluminescence in deep-sea creatures reveals a unique adaptation to extreme darkness. Certain species produce light through chemical reactions to attract prey, communicate, or deter predators. This niche biological function illustrates how life evolves specialized traits in response to environmental challenges. Which choice best describes the main idea of the text?
#
# A) The text explains how deep-sea creatures use bioluminescence as an adaptation to survive in darkness.
# B) The text describes the different colors of light produced by marine animals.
# C) The text argues that marine biology should focus more on ecosystems than individual species.
# D) The text claims that all deep-sea creatures use bioluminescence.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Environmental Science and Urban Ecology
#
# Urban ecology studies the interactions between living organisms and their urban environments. A nuanced aspect is how green roofs contribute to urban biodiversity by providing habitats for insects and birds in cities. These installations mitigate heat island effects and improve air quality by filtering pollutants. While green roofs are often valued for aesthetic and environmental reasons, their role in supporting urban wildlife is increasingly recognized. Which choice best describes the main idea of the text?
#
# A) Green roofs enhance urban biodiversity by providing habitats and mitigating environmental impacts.
# B) Green roofs are primarily installed for aesthetic purposes in urban areas.
# C) Urban ecology focuses solely on the study of air quality in cities.
# D) Green roofs increase the financial value of buildings without ecological effects.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# The study of pulsars, highly magnetized rotating neutron stars, has revealed valuable insights into the behavior of matter under extreme conditions. Pulsars emit beams of electromagnetic radiation observable when the beam points toward Earth, creating a lighthouse effect. Their precise rotational periods have made them useful tools for testing the laws of physics in strong gravitational fields. These observations contribute to our understanding of the universe's fundamental forces.
# Which choice best describes the main idea of the text?
#
# A. Pulsars provide critical information for studying the behavior of matter and physics under extreme conditions.
# B. Pulsars are the only celestial objects that emit electromagnetic radiation.
# C. The text explains the history of astronomy and its key discoveries.
# D. The passage focuses on how pulsars are used for navigation in space travel.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# During the Renaissance, artists developed innovative techniques such as chiaroscuro, which uses strong contrasts between light and dark to achieve a sense of volume in modeling three-dimensional objects and figures. This technique was not merely decorative but played a crucial role in enhancing the emotional depth and realism of the artwork. The meticulous application of chiaroscuro allowed painters to guide viewers’ attention and create dramatic effects, which fundamentally transformed the visual language of art. Which choice best describes the main idea of the text?
#
# A) Chiaroscuro was an important Renaissance technique that enhanced realism and emotional impact in paintings.
# B) Renaissance artists primarily focused on decorative patterns rather than emotional expression.
# C) Chiaroscuro was used mainly to depict landscapes in Renaissance paintings.
# D) Renaissance art techniques were static and lacked dramatic effects.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Renaissance Scientific Instruments
#
# During the Renaissance, the creation and use of scientific instruments marked a significant shift in the approach to empirical observation and measurement. Instruments such as the astrolabe and the early telescope were not only tools for navigation and astronomy but symbols of a growing emphasis on precision and experimentation. Artisans and scholars collaborated closely, blending craftsmanship with scientific inquiry. This period laid the groundwork for modern scientific methods by valuing reproducibility and careful documentation.
# Which choice best describes the main idea of the text?
#
# A) The Renaissance period was defined by the artistic beauty of scientific instruments.
# B) Renaissance scientific instruments exemplified a new focus on empirical observation and collaboration between artisans and scholars.
# C) Scientific instruments during the Renaissance were primarily used for decorative purposes in royal courts.
# D) The Renaissance was a period that rejected traditional methods in favor of purely theoretical science.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# The Indus Valley Civilization, one of the earliest urban cultures, developed advanced sanitation systems that were unprecedented in their time. Cities like Mohenjo-Daro featured intricate drainage and sewage systems, reflecting a high value placed on public hygiene. These innovations highlight the civilization's sophisticated urban planning and social organization, which influenced later societies. Which choice best describes the main idea of the text?
#
# A. The Indus Valley Civilization's urban planning included advanced sanitation systems, indicating a high level of social organization.
# B. The Indus Valley Civilization was the only ancient culture to develop urban sanitation systems.
# C. The Indus Valley Civilization's art and architecture were the most influential in history.
# D. The Indus Valley Civilization lacked any form of organized social structure.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# The evolution of gothic architecture in medieval Europe is often attributed to advancements in engineering, yet the nuanced role of stained glass windows in transforming interior light dynamics is less frequently discussed. These windows not only served aesthetic and religious functions but also influenced the structural design by allowing taller, thinner walls. This interplay between light, art, and engineering shaped the iconic look of gothic cathedrals. Which choice best describes the main idea of the text?
#
# A. Gothic architecture's defining features are primarily due to engineering feats rather than artistic elements.
# B. Stained glass windows in gothic cathedrals influenced both the aesthetic and structural design, shaping the architecture's distinctive character.
# C. Medieval gothic architecture was mostly focused on religious symbolism without regard to engineering challenges.
# D. The primary purpose of stained glass windows was to provide insulation and protect the interior from weather.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Renewable Energy Technology
#
# Advancements in renewable energy technology have increasingly focused on improving energy storage solutions, a critical component for maximizing the efficiency of solar and wind power systems. Recent innovations include the development of more durable and cost-effective batteries, as well as alternative storage methods such as thermal and mechanical systems. These improvements address the intermittent nature of renewable energy sources, enabling more consistent and reliable power delivery. Which choice best describes the main idea of the text?
#
# A. The main challenge in renewable energy technology is creating better energy storage to ensure consistent power supply.
# B. Renewable energy technology is primarily concerned with building more solar panels and wind turbines.
# C. Renewable energy technology is less effective than traditional energy sources because it is too costly.
# D. The paragraph explains how renewable energy systems have no issues related to power delivery.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Cognitive Psychology
#
# Cognitive psychology explores how humans process information, but a nuanced aspect is the role of mental imagery in problem-solving. Some studies suggest that visualizing a problem can activate similar brain regions as physically manipulating objects, enhancing understanding and memory. This phenomenon shows that mental representations can be as influential as sensory experiences in cognition. Which choice best describes the main idea of the text?
#
# A) Mental imagery plays a crucial role in cognitive processes by simulating physical experiences.
# B) Cognitive psychology is solely focused on memory and perception.
# C) Physical manipulation of objects is necessary for problem-solving.
# D) Sensory experiences are irrelevant in cognitive processes.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Ethnomusicology studies music in its cultural context, focusing on how music functions within different societies. A nuanced aspect of this field is the examination of musical instruments not just as tools for sound production but as symbols representing social identity, history, and spiritual beliefs. For instance, the use of specific drums in rituals can denote community hierarchy or ancestral connections. These instruments carry meaning beyond their musical use, which influences how they are perceived and preserved. Which choice best describes the main idea of the text?
#
# A) Ethnomusicology examines how musical instruments symbolize social and cultural meanings beyond their sound.
# B) Ethnomusicology focuses solely on the technical construction of musical instruments.
# C) Ethnomusicology aims to improve musical instrument manufacturing techniques.
# D) Ethnomusicology studies how music affects brain activity and cognitive functions.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# The evolution of maritime navigation techniques during the Age of Exploration was marked by gradual improvements in instrument precision, such as the astrolabe and later the sextant, which allowed sailors to ascertain their latitude more accurately. However, it was the development of the marine chronometer in the 18th century that revolutionized longitude determination, significantly reducing the risks of long sea voyages. This advancement not only enhanced trade efficiency but also expanded geographical knowledge. Which choice best describes the main idea of the text?
#
# A. The main idea is that the marine chronometer was a pivotal advancement in maritime navigation that improved safety and expanded knowledge.
# B. The text primarily discusses the cultural significance of maritime exploration during the Age of Exploration.
# C. The main idea is that the astrolabe was the most important navigation tool in history.
# D. The text explains how sailors used maps and compasses to explore new lands.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Medieval Literature
#
# During the medieval period, literature was deeply intertwined with religious and moral themes, often serving didactic purposes. One nuanced aspect is the use of allegory, where characters and events symbolically represent broader spiritual or ethical concepts. This technique allowed writers to convey complex theological ideas in a narrative form accessible to a largely illiterate population. Understanding medieval literature requires recognizing this symbolic layer, which reveals the text's deeper meanings beyond the surface story.
# Which choice best describes the main idea of the text?
#
# A. Medieval literature primarily uses allegory to communicate complex spiritual and ethical ideas.
# B. Medieval literature was mainly written for entertainment and had little moral instruction.
# C. Medieval literature is mostly historical accounts without symbolic meaning.
# D. All medieval literature was written by clergy and never included secular themes.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Ancient Mesopotamian Architecture
#
# Ancient Mesopotamian architecture is notable for its use of the ziggurat, a massive terraced structure that served religious purposes. These structures not only functioned as temples but also symbolized the connection between earth and the divine. The construction techniques involved mud bricks and innovative drainage systems, reflecting an advanced understanding of materials and urban planning. The significance of ziggurats extends beyond their physical form because they represent the cultural and spiritual priorities of Mesopotamian civilization.
# Which choice best describes the main idea of the text?
#
# A. The text describes the architectural features and cultural significance of Mesopotamian ziggurats.
# B. The text explains how Mesopotamian architecture was primarily focused on defensive structures.
# C. The text provides a detailed history of the Mesopotamian empire's political system.
# D. The text argues that Mesopotamian architecture was simple and lacked innovation.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# The development of solar panel efficiency has seen significant advancements through the integration of perovskite materials, which promise to reduce costs and increase energy conversion rates. Unlike traditional silicon-based cells, perovskite solar cells can be manufactured using less energy-intensive processes and flexible substrates, enabling wider application possibilities. However, challenges related to material stability and longevity remain before widespread commercial use is feasible. Which choice best describes the main idea of the text?
#
# A) The text explains how perovskite materials improve solar panel efficiency and their potential impact on renewable energy.
# B) The text details the history of solar panel development from silicon to modern materials.
# C) The text argues that perovskite solar cells are already widely used in commercial applications.
# D) The text describes the environmental impact of traditional silicon solar panels compared to fossil fuels.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# Historical Cartography
#
# Historical cartography reveals the evolution of mapmaking techniques from hand-drawn illustrations to the integration of scientific measurement tools. Early maps often reflected cultural biases and were more artistic than accurate, serving political or religious purposes. Over centuries, advancements like triangulation and the use of the compass enhanced precision, transforming maps into reliable geographic documents. This shift illustrates how technological and methodological progress affected the representation of the world. Which choice best describes the main idea of the text?
#
# A. The progression of mapmaking techniques from artistic to scientific reflects broader technological advancements.
# B. Early maps were mostly decorative and had no practical use.
# C. Maps have always been completely accurate representations of geography.
# D. Modern maps rely solely on artistic interpretation rather than scientific tools.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Quantum computing explores the use of quantum bits or qubits, which differ fundamentally from classical bits in their ability to represent both 0 and 1 simultaneously through superposition. This property, along with entanglement, enables quantum computers to perform certain calculations much more efficiently than traditional computers. Researchers focus on error correction methods and coherence time to make quantum systems more reliable. Which choice best describes the main idea of the text?
#
# A. Quantum computing leverages unique quantum properties to enhance computational power.
# B. Quantum computers are faster because they use smaller transistors than classical computers.
# C. Quantum computing has replaced classical computing in all applications.
# D. Quantum bits store information only as 0 or 1, similar to classical bits.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# The genre for the SAT passage is "History of Scientific Instruments."
#
# Passage:
# During the Renaissance, the development of scientific instruments such as the astrolabe and the telescope represented significant advancements not just in technology but in the way people understood the cosmos. These instruments allowed scientists and navigators to measure and observe the world with unprecedented precision. Their creation was a blend of art, craftsmanship, and scientific inquiry, reflecting a cultural shift toward empirical observation. Which choice best describes the main idea of the text?
#
# Answer choices:
# A. The Renaissance was primarily a period of artistic achievement rather than scientific progress.
# B. The development of scientific instruments during the Renaissance marked a cultural shift toward empirical observation and technological precision.
# C. Scientific instruments like the astrolabe were used mainly for decorative purposes during the Renaissance.
# D. The telescope was invented during the Renaissance solely for navigation purposes.
#
# Correct answer:
# B. The development of scientific instruments during the Renaissance marked a cultural shift toward empirical observation and technological precision.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# During the 18th century, botanical gardens were not only centers for plant collection but also hubs for scientific experimentation. Botanists used these gardens to study plant hybridization, leading to early understandings of genetics before the term was even coined. The exchange of plants between continents also influenced local ecosystems, sometimes beneficially and sometimes detrimentally. These gardens thus played a crucial role in advancing both horticulture and ecological awareness. Which choice best describes the main idea of the text?
#
# A. Botanical gardens in the 18th century were important for scientific studies and ecological impact.
# B. Botanical gardens were primarily designed for aesthetic enjoyment during the 18th century.
# C. The main purpose of 18th-century botanical gardens was to cultivate medicinal herbs exclusively.
# D. Botanical gardens had little influence on local ecosystems in the 18th century.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Urban archaeology focuses on uncovering the layers of human activity beneath modern cities, revealing how past societies adapted to urban life. Excavations often expose structures, artifacts, and waste that provide insight into economic, social, and environmental practices of previous inhabitants. This field requires balancing preservation with contemporary development demands, often complicating archaeological efforts. Urban archaeologists must also interpret fragmented evidence to reconstruct historical urban landscapes and understand the evolution of city planning, because
# Which choice best describes the main idea of the text?
#
# A. Urban archaeology investigates past urban life by analyzing physical remnants beneath cities.
# B. Urban archaeology primarily focuses on preserving ancient rural settlements.
# C. Urban archaeologists mainly study natural landscapes to understand human history.
# D. Urban archaeology is concerned with modern urban development without historical context.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Bioluminescence in Deep Sea Creatures
#
# Paragraph:
# Bioluminescence is a fascinating adaptation seen in many deep sea creatures, used primarily for communication, camouflage, and predation. These organisms produce light through chemical reactions within their bodies, which often serves specific functions such as attracting mates or luring prey. The intensity and color of the emitted light vary among species, reflecting their unique ecological niches. This natural phenomenon reveals complex evolutionary strategies tailored to the deep ocean's darkness.
# Which choice best describes the main idea of the text?
#
# Answer Choices:
# A. The main purpose of bioluminescence in deep sea creatures is to serve as an adaptive mechanism for survival in the dark ocean environment.
# B. Bioluminescence is mostly used by deep sea creatures to navigate long distances in the ocean.
# C. Deep sea creatures produce bioluminescence primarily for aesthetic purposes to attract human observers.
# D. Bioluminescence in deep sea creatures is a random byproduct of other biological processes, with no specific function.
#
# Correct Answer:
# A
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# The genre is Marine Biology.
#
# Paragraph:
# The study of bioluminescence within marine biology explores how certain marine organisms produce and emit light through chemical reactions. This phenomenon is not just for illumination but serves various ecological functions such as attracting mates, deterring predators, and luring prey. Researchers focus on the molecular mechanisms behind bioluminescence and its evolutionary advantages in deep-sea environments. Which choice best describes the main idea of the text?
#
# Answer Choices:
# A. The paragraph explains the ecological roles and molecular basis of bioluminescence in marine organisms.
# B. The paragraph discusses the dangers faced by marine organisms in deep-sea environments.
# C. The paragraph describes various types of marine organisms that live in the ocean.
# D. The paragraph outlines the history of marine biology as a scientific field.
#
# Correct Answer:
# A. The paragraph explains the ecological roles and molecular basis of bioluminescence in marine organisms.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Historical Architecture
#
# The evolution of Gothic cathedrals during the Middle Ages reveals a complex interplay between religious aspirations and engineering innovations. Builders developed flying buttresses not only to support higher walls and larger stained-glass windows but also to create an ethereal atmosphere inside the cathedrals. These architectural choices reflected a desire to inspire awe and convey spiritual transcendence. Which choice best describes the main idea of the text?
#
# A) The construction of flying buttresses was mainly to enhance the aesthetic appeal of Gothic cathedrals.
# B) Gothic cathedral architecture combined engineering and religious goals to create inspiring spaces.
# C) Medieval cathedrals primarily focused on maximizing interior space for large congregations.
# D) Flying buttresses were an early form of decorative art without practical use.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# ...
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c4aca90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a5390>, 576140.10994975)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c410e50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c4b2250>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a7ee0>, 576147.43650705)])']
# connector: <aiohttp.connector.TCPConnector object at 0x104fb1950>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5f9750>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a64a0>, 576157.081355855)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c5c3c90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c6d6ed0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a6890>, 576167.874205037)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c6d5ed0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5fec90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a7620>, 576181.778610049)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c5ffe50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c58fc90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c552200>, 576189.094466037)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c58da50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c797690>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c551860>, 576196.199459223)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c794d10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c6e63d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c551b00>, 576210.294629914)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c6e4c10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c4ef450>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c553d20>, 576221.340769485)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c4eeed0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c713850>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c553540>, 576230.201925847)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c5bd790>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c52a990>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c550bb0>, 576243.135661078)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c6d5b90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c7fd090>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c5501a0>, 576253.756776201)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c7fc650>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c8a6a90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c553310>, 576263.220416097)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c8a5dd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c670cd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c550440>, 576276.076610933)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c349e90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c3ccd10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c56b150>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c553e70>, 576296.544910273)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c568bd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c841c90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c550600>, 576307.01780964)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c841f50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c4100d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c552dd0>, 576314.554103745)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c436810>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c39e5d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c550fa0>, 576324.702638064)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c39d090>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c792f10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c552cf0>, 576332.988704265)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c6cf150>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c6e09d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c6675b0>, 576348.306291431)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c6e2b90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5d30d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c6644b0>, 576358.497568637)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c4ddb50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c8dc990>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a6820>, 576368.859977552)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c8dd3d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c878f90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c553f50>, 576376.585661195)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c318750>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c60a450>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a6510>, 576384.951713492)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c60af50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c540fd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c552c80>, 576397.460590339)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c543e90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c573550>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c552660>, 576407.145768197)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c570310>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c713ed0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c6654e0>, 576416.265312268)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c3b8610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c6e3d90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c6674d0>, 576427.358899239)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c37a610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c672090>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c666dd0>, 576433.671688155)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c673810>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5be9d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c664c20>, 576450.974826372)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c5bc650>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5ae1d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c666d60>, 576460.087091667)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c7e7410>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5f4450>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c666ba0>, 576467.042473626)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c5f5450>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c8aa2d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c664fa0>, 576480.274856383)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c8a86d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c962210>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c3a62e0>, 576488.794832856)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c963750>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c44f050>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c551390>, 576501.125359323)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c395250>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c58b550>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c666900>, 576507.531466451)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c5701d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c7e8d50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c6647c0>, 576520.217204992)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c7e9050>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c7cfb10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c665080>, 576528.558176855)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c7cdd10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c86ac10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c6660b0>, 576543.521849699)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c868e10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c87d290>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c666c10>, 576553.198332658)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c794e10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c6c8350>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c664280>, 576566.232952889)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c71f550>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c7084d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c739a20>, 576574.801472881)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c70a1d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c60a350>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c739be0>, 576584.596711322)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c915150>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10c5869d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x10c665b70>, 576600.185218529)])']
# connector: <aiohttp.connector.TCPConnector object at 0x10c587f90>
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Recent studies in neuroscience have focused on the hippocampus, a brain region critical for memory formation. Researchers have discovered that the hippocampus not only stores memories but also actively reorganizes them during sleep, which enhances long-term retention. This reorganization process involves neural plasticity, allowing the brain to strengthen important memories while discarding irrelevant information. Such findings suggest that memory is not static but dynamic, continuously evolving with experience and rest. Which choice best describes the main idea of the text?
#
# A. Memory formation involves active reorganization in the hippocampus during sleep.
# B. The hippocampus is primarily responsible for controlling emotions.
# C. Memories are permanently stored in the brain without change.
# D. Sleep has no effect on memory retention.Historical Archaeology
# Marine Biology
# Neoclassical Architecture
# Renaissance Art
# Environmental Science
# Medieval Architecture
# Quantum Physics
# Ancient Pottery
# Ancient Architectural Techniques
# Ancient Architecture
# Impressionist Art
# Historical Maritime Navigation
# Astrobiology
# Medieval Manuscript Art
# Medieval Manuscript Illumination
# Astrophysics
# Ancient Maritime Archaeology
# Environmental Science and Urban Ecology
# Astronomy
# Renaissance Art Techniques
# Renaissance Scientific Instruments
# Ancient Civilizations
# Architectural History
# Renewable Energy Technology
# Cognitive Psychology
# Ethnomusicology
# History of Maritime Navigation
# Medieval Literature
# Ancient Mesopotamian Architecture
# Renewable Energy Technologies
# Historical Cartography
# Quantum Computing
# History of Scientific Instruments
# Historical Botany
# Urban Archaeology
# Bioluminescence in Deep Sea Creatures
# Historical Architecture
# Geological Formations of Desert Landscapes
# Urban Green Spaces
# Ancient Navigation Methods
# Classical Music Composition Techniques
# Renaissance Scientific Illustration
# Ancient Navigation Techniques
# Medieval Manuscripts
# Urban Sociology
# Cryptozoology
# Ancient Metallurgy
# Urban Architecture
# Architectural history
# Quantum Physics in Computing
# Historical Geography
# Classical Music Composition
# Evolution of Urban Street Art
# Urban Planning
# Marine Archaeology
# Astronomical Instrumentation
# Victorian Era Urban Planning
# Botanical Illustration
# Victorian Era Botanical Illustration
# Quantum Mechanics
# Forensic Anthropology
# Victorian Era Sanitation Systems
# 19th Century American Literature
# Insect Behavior
# History of Navigation
# Paleontology
# Renaissance Architecture
# Cognitive Neuroscience
# Astrophysics and Black Holes
# Art Conservation
# Architectural Acoustics
# Ethnobotany
# Ancient Mesopotamian Literature
# Behavioral Ecology
# Underwater Archaeology
# Ecological Impact of Urban Green Spaces
# Art History
# History of Cartography
# Neuropsychology
# Ancient Egyptian Architecture
# Medieval Manuscript Studies
# Architectural History of Gothic Cathedrals
# Impressionist Painting
# Ancient Mesopotamian Trade
# Cultural Anthropology
# Digital Archaeology
# Historical Linguistics
# Ancient Astronomy
# Mythical Symbolism in Renaissance Art
# Ethnomusicology of the Silk Road
# Victorian Era Garden Design
# Anthropology
# Ancient Egyptian Art
# Botany
# Marine Ecology
# Neuroscience and Memory Formation

# %%
# Print generated genres (one per question)
for genre in para.keys():
    print(genre)
# Out:
# Historical Archaeology
# Marine Biology
# Neoclassical Architecture
# Renaissance Art
# Environmental Science
# Medieval Architecture
# Quantum Physics
# Ancient Pottery
# Ancient Architectural Techniques
# Ancient Architecture
# Impressionist Art
# Historical Maritime Navigation
# Astrobiology
# Medieval Manuscript Art
# Medieval Manuscript Illumination
# Astrophysics
# Ancient Maritime Archaeology
# Environmental Science and Urban Ecology
# Astronomy
# Renaissance Art Techniques
# Renaissance Scientific Instruments
# Ancient Civilizations
# Architectural History
# Renewable Energy Technology
# Cognitive Psychology
# Ethnomusicology
# History of Maritime Navigation
# Medieval Literature
# Ancient Mesopotamian Architecture
# Renewable Energy Technologies
# Historical Cartography
# Quantum Computing
# History of Scientific Instruments
# Historical Botany
# Urban Archaeology
# Bioluminescence in Deep Sea Creatures
# Historical Architecture
# Geological Formations of Desert Landscapes
# Urban Green Spaces
# Ancient Navigation Methods
# Classical Music Composition Techniques
# Renaissance Scientific Illustration
# Ancient Navigation Techniques
# Medieval Manuscripts
# Urban Sociology
# Cryptozoology
# Ancient Metallurgy
# Urban Architecture
# Architectural history
# Quantum Physics in Computing
# Historical Geography
# Classical Music Composition
# Evolution of Urban Street Art
# Urban Planning
# Marine Archaeology
# Astronomical Instrumentation
# Victorian Era Urban Planning
# Botanical Illustration
# Victorian Era Botanical Illustration
# Quantum Mechanics
# Forensic Anthropology
# Victorian Era Sanitation Systems
# 19th Century American Literature
# Insect Behavior
# History of Navigation
# Paleontology
# Renaissance Architecture
# Cognitive Neuroscience
# Astrophysics and Black Holes
# Art Conservation
# Architectural Acoustics
# Ethnobotany
# Ancient Mesopotamian Literature
# Behavioral Ecology
# Underwater Archaeology
# Ecological Impact of Urban Green Spaces
# Art History
# History of Cartography
# Neuropsychology
# Ancient Egyptian Architecture
# Medieval Manuscript Studies
# Architectural History of Gothic Cathedrals
# Impressionist Painting
# Ancient Mesopotamian Trade
# Cultural Anthropology
# Digital Archaeology
# Historical Linguistics
# Ancient Astronomy
# Mythical Symbolism in Renaissance Art
# Ethnomusicology of the Silk Road
# Victorian Era Garden Design
# Anthropology
# Ancient Egyptian Art
# Botany
# Marine Ecology
# Neuroscience and Memory Formation

# %%
for key in para:
    print(json.dumps(para[key]))
# Out:
# {"genre": "Historical Archaeology", "question": "Historical archaeology focuses on the study of cultures and societies with written records, often combining physical artifacts with historical documents to gain a fuller understanding. Unlike prehistoric archaeology, it benefits from corroborating texts that provide context to the material finds. However, the interpretation of these findings requires careful consideration of biases in written sources and the archaeological record itself. This interplay between tangible evidence and textual information shapes our understanding of past human behaviors.\nWhich choice best describes the main idea of the text?", "ans_choices": ["Historical archaeology integrates both material artifacts and written records to better understand past cultures.", "Historical archaeology primarily relies on written records and disregards physical artifacts.", "Historical archaeology studies only prehistoric societies without written records.", "Historical archaeology only relies on physical artifacts to interpret the past."], "ans_choices_with_explanation": {"Historical archaeology integrates both material artifacts and written records to better understand past cultures.": "This choice correctly summarizes the main idea by highlighting the integration of artifacts and documents.", "Historical archaeology primarily relies on written records and disregards physical artifacts.": "This choice is tempting but incorrect because the text emphasizes the importance of both artifacts and documents.", "Historical archaeology studies only prehistoric societies without written records.": "This choice is incorrect as it contradicts the text's focus on societies with written records.", "Historical archaeology only relies on physical artifacts to interpret the past.": "This choice is incorrect because the text stresses the combination of artifacts and written records."}, "correct_answer": "Historical archaeology integrates both material artifacts and written records to better understand past cultures."}
# {"genre": "Marine Biology", "question": "The study of bioluminescence in marine organisms reveals an intricate communication system that is both chemical and visual. Certain species use bioluminescence to attract mates, while others use it for camouflage or to deter predators. This natural phenomenon is highly adapted to the darkness of deep-sea environments, where light is scarce. The complexity of these light signals varies among species, which suggests an evolutionary advantage in their specific ecological niches. Which choice best describes the main idea of the text?", "ans_choices": ["A. Bioluminescence in marine organisms serves multiple ecological functions and varies in complexity among species.", "B. Bioluminescence is primarily used by marine organisms to attract mates in deep-sea environments.", "C. Marine organisms rely on bioluminescence to produce food in the absence of sunlight.", "D. Bioluminescence causes marine organisms to be more visible to predators in all environments."], "ans_choices_with_explanation": {"A. Bioluminescence in marine organisms serves multiple ecological functions and varies in complexity among species.": "This choice accurately summarizes the main idea about the diverse roles and complexity of bioluminescence.", "B. Bioluminescence is primarily used by marine organisms to attract mates in deep-sea environments.": "This choice is tempting but too narrow, ignoring other functions of bioluminescence.", "C. Marine organisms rely on bioluminescence to produce food in the absence of sunlight.": "This choice is incorrect because the text does not mention bioluminescence as a food production method.", "D. Bioluminescence causes marine organisms to be more visible to predators in all environments.": "This choice is incorrect because the text states bioluminescence can also deter predators and aid in camouflage."}, "correct_answer": "A"}
# {"genre": "Neoclassical Architecture", "question": "Neoclassical architecture, emerging in the mid-18th century, draws heavily on the principles of classical antiquity, emphasizing simplicity and symmetry. A niche aspect of this style is the revival of Greek orders, particularly the Doric and Ionic, which were adapted to modern construction techniques of the time. This blend of ancient design with contemporary methods allowed architects to achieve grandeur without excessive ornamentation. The style also reflects Enlightenment ideals, where rationality and clarity were paramount. Which choice best describes the main idea of the text?", "ans_choices": ["Neoclassical architecture revives Greek architectural orders using modern building techniques to achieve simplicity and grandeur.", "Neoclassical architecture is characterized by its ornate decoration and complex structures.", "Neoclassical architecture originated in ancient Greece and was forgotten until the 20th century.", "Neoclassical architecture primarily focuses on Gothic elements and medieval designs."], "ans_choices_with_explanation": {"Neoclassical architecture revives Greek architectural orders using modern building techniques to achieve simplicity and grandeur.": "This choice accurately summarizes the main idea highlighting the revival and adaptation of Greek orders with modern methods.", "Neoclassical architecture is characterized by its ornate decoration and complex structures.": "This choice is incorrect because the text emphasizes simplicity and lack of excessive ornamentation.", "Neoclassical architecture originated in ancient Greece and was forgotten until the 20th century.": "This choice is factually incorrect as the text states the style emerged in the 18th century and is a revival, not an original ancient style.", "Neoclassical architecture primarily focuses on Gothic elements and medieval designs.": "This choice is incorrect because the text clearly states the focus is on classical antiquity, not Gothic or medieval designs."}, "correct_answer": "Neoclassical architecture revives Greek architectural orders using modern building techniques to achieve simplicity and grandeur."}
# {"genre": "Renaissance Art", "question": "During the Renaissance, artists developed techniques such as chiaroscuro and linear perspective to enhance the realism of their paintings. These methods allowed for more accurate depictions of light and depth, which contributed to the vividness of the scenes portrayed. This shift in artistic approach marked a departure from the flatter, more symbolic representations of earlier periods, influencing how viewers engaged with visual narratives. Which choice best describes the main idea of the text?", "ans_choices": ["The Renaissance introduced new artistic techniques that improved the realism and depth of paintings.", "Renaissance artists primarily focused on religious symbolism in their work.", "Renaissance art was less detailed than earlier art forms.", "Artists in the Renaissance used abstract forms to convey emotion."], "ans_choices_with_explanation": {"The Renaissance introduced new artistic techniques that improved the realism and depth of paintings.": "This choice correctly identifies the main idea about the impact of new techniques on Renaissance art.", "Renaissance artists primarily focused on religious symbolism in their work.": "This is incorrect because the passage emphasizes realism over symbolism.", "Renaissance art was less detailed than earlier art forms.": "This is clearly incorrect as the passage discusses increased detail and realism.", "Artists in the Renaissance used abstract forms to convey emotion.": "This is incorrect because the passage focuses on realism and perspective, not abstraction."}, "correct_answer": "The Renaissance introduced new artistic techniques that improved the realism and depth of paintings."}
# {"genre": "Environmental Science", "question": "The study of microplastics in ocean ecosystems has revealed their pervasive presence even in remote marine environments. These tiny plastic particles often originate from larger debris that breaks down over time. Researchers have started focusing on the impact of microplastics on marine life, particularly filter feeders such as mussels and plankton. These organisms ingest microplastics, which can then bioaccumulate through the food chain, potentially affecting larger marine animals and humans. This area of study is crucial because it highlights the unseen consequences of plastic pollution on ocean health.\nWhich choice best describes the main idea of the text?", "ans_choices": ["Microplastics in oceans pose a significant threat to marine ecosystems by entering the food chain.", "Plastic pollution is only a problem in heavily populated coastal areas.", "Microplastics have no impact on marine organisms because they are too small to be ingested.", "Marine animals are unaffected by pollution due to their natural resilience."], "ans_choices_with_explanation": {"Microplastics in oceans pose a significant threat to marine ecosystems by entering the food chain.": "This choice correctly captures the main idea of the paragraph regarding microplastics impacting marine life through the food chain.", "Plastic pollution is only a problem in heavily populated coastal areas.": "This choice is tempting but unsupported because the text mentions microplastics in remote areas, not just populated ones.", "Microplastics have no impact on marine organisms because they are too small to be ingested.": "This is incorrect as the paragraph states that filter feeders ingest microplastics.", "Marine animals are unaffected by pollution due to their natural resilience.": "This is clearly incorrect and contradicts the information about bioaccumulation and potential effects on marine animals."}, "correct_answer": "Microplastics in oceans pose a significant threat to marine ecosystems by entering the food chain."}
# {"genre": "Medieval Architecture", "question": "Medieval architecture is often recognized for its grand cathedrals and castles, but a less discussed aspect is the use of flying buttresses to support walls and allow for higher ceilings and larger windows. These structural innovations not only enhanced the aesthetic appeal but also improved the functionality of buildings by distributing weight more efficiently. Understanding this architectural technique reveals how engineering and artistry intertwined during this period. Which choice best describes the main idea of the text?", "ans_choices": ["The text explains how flying buttresses improved both the structural integrity and design of medieval buildings.", "The text describes the religious symbolism behind medieval cathedrals.", "The text outlines the political history of medieval castle construction.", "The text emphasizes the use of medieval architecture in modern city planning."], "ans_choices_with_explanation": {"The text explains how flying buttresses improved both the structural integrity and design of medieval buildings.": "This choice correctly identifies the main focus on flying buttresses' dual role in medieval architecture.", "The text describes the religious symbolism behind medieval cathedrals.": "This choice is unsupported as the text does not discuss religious symbolism.", "The text outlines the political history of medieval castle construction.": "This is incorrect because the text focuses on architectural techniques, not political history.", "The text emphasizes the use of medieval architecture in modern city planning.": "This choice is clearly incorrect as the text does not mention modern city planning."}, "correct_answer": "The text explains how flying buttresses improved both the structural integrity and design of medieval buildings."}
# {"genre": "Quantum Physics", "question": "Quantum entanglement challenges classical notions of locality by suggesting that particles can instantaneously affect each other's states regardless of distance. This phenomenon, which Einstein famously referred to as \"spooky action at a distance,\" has profound implications for the future of communication and computing technologies. Researchers continue to explore how entanglement can be harnessed in practical applications, such as quantum cryptography and quantum teleportation. Which choice best describes the main idea of the text?", "ans_choices": ["Quantum entanglement reveals non-local connections between particles that have potential applications in advanced technologies.", "Quantum entanglement disproves all classical physics theories about particle behavior.", "Quantum entanglement is a simple phenomenon easily explained by classical physics.", "Quantum entanglement is only a theoretical concept with no practical use."], "ans_choices_with_explanation": {"Quantum entanglement reveals non-local connections between particles that have potential applications in advanced technologies.": "This choice accurately captures the main idea of the paragraph about entanglement and its implications.", "Quantum entanglement disproves all classical physics theories about particle behavior.": "This choice overstates the implications and is not supported by the paragraph.", "Quantum entanglement is a simple phenomenon easily explained by classical physics.": "This choice is clearly incorrect as the paragraph emphasizes the complexity and uniqueness of entanglement.", "Quantum entanglement is only a theoretical concept with no practical use.": "This choice contradicts the paragraph's mention of practical applications like quantum cryptography."}, "correct_answer": "Quantum entanglement reveals non-local connections between particles that have potential applications in advanced technologies."}
# {"genre": "Ancient Pottery", "question": "The study of ancient pottery reveals insights into the daily lives and trade practices of early civilizations. Pottery styles and materials often varied significantly between regions, reflecting local resources and cultural influences. The evolution of pottery techniques, from hand-building to wheel-throwing, marks technological advancements within societies. Additionally, the distribution of pottery shards can indicate ancient trade routes and interactions. Which choice best describes the main idea of the text?", "ans_choices": ["Ancient pottery provides valuable information about early human societies and their technological and trade developments.", "Ancient pottery was primarily used for decorative purposes in early civilizations.", "Pottery techniques remained unchanged throughout ancient history.", "Ancient pottery is only important for understanding artistic styles."], "ans_choices_with_explanation": {"Ancient pottery provides valuable information about early human societies and their technological and trade developments.": "This choice accurately captures the main idea by encompassing the cultural, technological, and trade aspects discussed.", "Ancient pottery was primarily used for decorative purposes in early civilizations.": "This choice is tempting but unsupported, as the text focuses on pottery's functional and cultural significance, not decoration.", "Pottery techniques remained unchanged throughout ancient history.": "This is incorrect because the text specifically mentions the evolution from hand-building to wheel-throwing.", "Ancient pottery is only important for understanding artistic styles.": "This is clearly incorrect as the text emphasizes technological and trade aspects, not just art."}, "correct_answer": "Ancient pottery provides valuable information about early human societies and their technological and trade developments."}
# {"genre": "Ancient Architectural Techniques", "question": "In ancient architectural techniques, the use of interlocking stones without mortar exemplified both engineering ingenuity and aesthetic values. This method not only provided structural stability but also allowed buildings to withstand natural disasters like earthquakes. The precision required to craft these stones reflects advanced knowledge of geometry and material properties. Such construction methods highlight a sophisticated understanding of balance and durability, which ancient builders achieved through painstaking manual labor and skill.\nWhich choice best describes the main idea of the text?", "ans_choices": ["Ancient builders used interlocking stones to create earthquake-resistant structures demonstrating advanced engineering skills.", "Ancient architecture was primarily focused on aesthetic beauty rather than functionality.", "Ancient builders lacked knowledge of geometry and used mortar extensively.", "Ancient architectural techniques were simple and required little skill."], "ans_choices_with_explanation": {"Ancient builders used interlocking stones to create earthquake-resistant structures demonstrating advanced engineering skills.": "This choice correctly identifies the main idea about engineering ingenuity and structural stability in ancient techniques.", "Ancient architecture was primarily focused on aesthetic beauty rather than functionality.": "This is tempting but unsupported since the text emphasizes both engineering and aesthetic values, not just beauty.", "Ancient builders lacked knowledge of geometry and used mortar extensively.": "This is clearly incorrect as the text states the opposite, highlighting advanced geometry knowledge and no mortar use.", "Ancient architectural techniques were simple and required little skill.": "This is clearly incorrect; the text emphasizes the complexity and skill involved."}, "correct_answer": "Ancient builders used interlocking stones to create earthquake-resistant structures demonstrating advanced engineering skills."}
# {"genre": "Ancient Architecture", "question": "The use of corbel arches in ancient architecture represents a distinctive engineering method that predates the development of the true arch. Unlike the true arch, which distributes weight evenly through a keystone, corbel arches rely on overlapping stones that gradually extend toward the center. This approach was instrumental in creating larger interior spaces in early structures and illustrates an incremental step in architectural innovation. Which choice best describes the main idea of the text?", "ans_choices": ["The paragraph explains how corbel arches differ from true arches in ancient architecture.", "The paragraph details the aesthetic beauty of corbel arches in ancient buildings.", "The paragraph describes the use of modern materials in ancient architecture.", "The paragraph argues that corbel arches were less effective than true arches."], "ans_choices_with_explanation": {"The paragraph explains how corbel arches differ from true arches in ancient architecture.": "This choice correctly summarizes the main idea about the engineering differences and significance of corbel arches.", "The paragraph details the aesthetic beauty of corbel arches in ancient buildings.": "This is incorrect because the paragraph focuses on structural and engineering aspects, not aesthetics.", "The paragraph describes the use of modern materials in ancient architecture.": "This is clearly incorrect as the paragraph discusses ancient techniques, not modern materials.", "The paragraph argues that corbel arches were less effective than true arches.": "This is incorrect because the paragraph does not make comparative judgments about effectiveness, only describes the method and its role."}, "correct_answer": "The paragraph explains how corbel arches differ from true arches in ancient architecture."}
# {"genre": "Impressionist Art", "question": "Impressionist art, emerging in the late 19th century, revolutionized traditional painting by focusing on light and color over detail. Artists often painted en plein air to capture the fleeting effects of natural light. This approach challenged established artistic norms and emphasized perception rather than realism. The movement's emphasis on spontaneity and everyday scenes distinguished it from previous art styles. Which choice best describes the main idea of the text?", "ans_choices": ["Impressionist art primarily focuses on capturing the changing effects of light and color in natural settings.", "Impressionist art seeks to portray historical and mythological subjects in great detail.", "Impressionist artists strictly adhered to classical techniques and realistic depictions.", "Impressionist art exclusively uses dark colors to convey mood and emotion."], "ans_choices_with_explanation": {"Impressionist art primarily focuses on capturing the changing effects of light and color in natural settings.": "This choice accurately reflects the paragraph's emphasis on light, color, and natural scenes.", "Impressionist art seeks to portray historical and mythological subjects in great detail.": "This choice is unsupported as the paragraph emphasizes everyday scenes and spontaneity, not historical or mythological subjects.", "Impressionist artists strictly adhered to classical techniques and realistic depictions.": "This choice contradicts the paragraph which highlights the movement's break from traditional techniques and realism.", "Impressionist art exclusively uses dark colors to convey mood and emotion.": "This choice is incorrect because the paragraph focuses on light and color, not exclusively dark colors."}, "correct_answer": "Impressionist art primarily focuses on capturing the changing effects of light and color in natural settings."}
# {"genre": "Historical Maritime Navigation", "question": "During the Age of Exploration, mariners relied on a combination of celestial navigation and rudimentary maps to traverse vast oceans. One particularly nuanced aspect of this practice was the use of the astrolabe to measure the altitude of the sun or stars above the horizon, which helped sailors determine their latitude. Despite its importance, the astrolabe had limitations in accuracy and was often supplemented by dead reckoning. This blend of tools and techniques highlights the complexity of early maritime navigation.\nWhich choice best describes the main idea of the text?", "ans_choices": ["The text explains how early sailors combined different tools to navigate the seas effectively.", "The text details the construction and design of the astrolabe.", "The text argues that celestial navigation was more accurate than dead reckoning.", "The text provides a biography of famous explorers from the Age of Exploration."], "ans_choices_with_explanation": {"The text explains how early sailors combined different tools to navigate the seas effectively.": "This choice accurately summarizes the main idea about the combination of tools for navigation.", "The text details the construction and design of the astrolabe.": "This choice is unsupported as the text focuses on navigation techniques, not astrolabe design.", "The text argues that celestial navigation was more accurate than dead reckoning.": "This is incorrect because the text states the astrolabe had limitations and was supplemented by dead reckoning.", "The text provides a biography of famous explorers from the Age of Exploration.": "This is clearly incorrect as the text does not mention any explorers or biographies."}, "correct_answer": "The text explains how early sailors combined different tools to navigate the seas effectively."}
# {"genre": "Astrobiology", "question": "Astrobiology explores the potential for life beyond Earth, focusing on extreme environments within our solar system where life might exist. Recent studies emphasize the icy moons of Jupiter and Saturn, such as Europa and Enceladus, which have subsurface oceans beneath their frozen crusts. These environments offer conditions similar to Earth's deep ocean hydrothermal vents, where life thrives without sunlight. Understanding these parallels guides the search for extraterrestrial life and informs future exploratory missions. \nWhich choice best describes the main idea of the text?", "ans_choices": ["The main focus of astrobiology is the study of hydrothermal vents on Earth.", "Astrobiology investigates environments on icy moons that may support life, drawing parallels with Earth's extreme habitats.", "Astrobiology is primarily concerned with the geological features of Jupiter and Saturn.", "Astrobiology proves that life exists on Europa and Enceladus."], "ans_choices_with_explanation": {"The main focus of astrobiology is the study of hydrothermal vents on Earth.": "This is incorrect because the text discusses icy moons, not Earth hydrothermal vents specifically.", "Astrobiology investigates environments on icy moons that may support life, drawing parallels with Earth's extreme habitats.": "This is correct as it accurately reflects the text's emphasis on icy moons and their potential for life.", "Astrobiology is primarily concerned with the geological features of Jupiter and Saturn.": "This is incorrect because the text focuses on biological potential, not geology of the planets themselves.", "Astrobiology proves that life exists on Europa and Enceladus.": "This is incorrect as the text only suggests the possibility of life, not proof."}, "correct_answer": "Astrobiology investigates environments on icy moons that may support life, drawing parallels with Earth's extreme habitats."}
# {"genre": "Medieval Manuscript Art", "question": "Medieval manuscript art often featured intricate illuminations that served purposes beyond decoration, such as conveying theological or philosophical concepts through symbolic imagery. Artists used specific colors and motifs to guide the reader\u2019s understanding of sacred texts, creating a visual narrative that complemented the written word. These illuminations were not merely ornamental but functioned as educational tools in monastic communities. Which choice best describes the main idea of the text?", "ans_choices": ["Illuminations in medieval manuscripts primarily served decorative purposes.", "Medieval manuscript illuminations were a complex visual language that enhanced understanding of religious texts.", "The primary function of medieval manuscripts was to preserve historical events.", "Medieval manuscript art was mainly produced for wealthy patrons and had little educational use."], "ans_choices_with_explanation": {"Illuminations in medieval manuscripts primarily served decorative purposes.": "This is incorrect because the paragraph states illuminations conveyed deeper meanings beyond decoration.", "Medieval manuscript illuminations were a complex visual language that enhanced understanding of religious texts.": "This is correct as it captures the main idea that illuminations conveyed theological and philosophical concepts.", "The primary function of medieval manuscripts was to preserve historical events.": "This is incorrect because the paragraph focuses on illuminations' educational and symbolic roles, not historical recording.", "Medieval manuscript art was mainly produced for wealthy patrons and had little educational use.": "This is incorrect since the paragraph emphasizes the educational role of illuminations in monastic communities, not patronage."}, "correct_answer": "Medieval manuscript illuminations were a complex visual language that enhanced understanding of religious texts."}
# {"genre": "Medieval Manuscript Illumination", "question": "Medieval manuscript illumination involved the intricate decoration of texts using gold, silver, and vivid colors to enhance the visual appeal and spiritual significance of religious and secular works. Artists often employed a mix of naturalistic and symbolic imagery to convey complex theological and philosophical ideas. This art form was not merely ornamental but served to guide the reader\u2019s interpretation and meditation on the text. Which choice best describes the main idea of the text?", "ans_choices": ["The paragraph explains that medieval manuscript illumination was purely decorative with no deeper purpose.", "Medieval manuscript illumination combined artistic techniques and symbolic imagery to enhance understanding of texts.", "The text focuses on the technological methods used in manuscript production during the medieval period.", "The paragraph describes the economic impact of manuscript illumination on medieval society."], "ans_choices_with_explanation": {"The paragraph explains that medieval manuscript illumination was purely decorative with no deeper purpose.": "This is incorrect because the paragraph emphasizes illumination's role in guiding interpretation, not just decoration.", "Medieval manuscript illumination combined artistic techniques and symbolic imagery to enhance understanding of texts.": "This is correct because the paragraph highlights both artistic detail and symbolic meaning in illumination.", "The text focuses on the technological methods used in manuscript production during the medieval period.": "This is incorrect as the paragraph does not discuss production technology but artistic and symbolic aspects.", "The paragraph describes the economic impact of manuscript illumination on medieval society.": "This is incorrect because the paragraph does not address economic effects but artistic and interpretive functions."}, "correct_answer": "Medieval manuscript illumination combined artistic techniques and symbolic imagery to enhance understanding of texts."}
# {"genre": "Astrophysics", "question": "Astrophysics often focuses on the study of celestial phenomena, but the behavior of neutron stars presents a particularly intriguing niche. These remnants of massive stars exhibit extreme densities and magnetic fields, creating conditions that challenge our understanding of physics. Observing their spin rates and emitted radiation patterns reveals insights into matter under intense pressure. Studying neutron stars helps scientists explore fundamental forces in the universe, which are otherwise inaccessible in terrestrial laboratories.\nWhich choice best describes the main idea of the text?", "ans_choices": ["The text explains how neutron stars provide unique insights into extreme physical conditions in the universe.", "The text describes the general characteristics of all celestial bodies in space.", "The text argues that neutron stars are the most important objects in astrophysics.", "The text details the history of astrophysics as a scientific field."], "ans_choices_with_explanation": {"The text explains how neutron stars provide unique insights into extreme physical conditions in the universe.": "This choice accurately captures the main idea about neutron stars offering insights into fundamental forces.", "The text describes the general characteristics of all celestial bodies in space.": "This is incorrect as the text specifically focuses on neutron stars, not all celestial bodies.", "The text argues that neutron stars are the most important objects in astrophysics.": "This is unsupported because the text does not claim neutron stars are the most important astrophysical objects.", "The text details the history of astrophysics as a scientific field.": "This is incorrect since the text does not discuss the history of astrophysics at all."}, "correct_answer": "The text explains how neutron stars provide unique insights into extreme physical conditions in the universe."}
# {"genre": "Ancient Maritime Archaeology", "question": "Ancient maritime archaeology focuses on the study of shipwrecks and submerged ports to uncover historical trade routes and cultural exchanges. Unlike terrestrial archaeology, it requires specialized underwater excavation techniques and technology to preserve fragile artifacts. The discipline has revealed insights into ancient economies and navigation methods, but challenges such as site accessibility and conservation remain significant. These factors shape how researchers interpret the maritime past. Which choice best describes the main idea of the text?", "ans_choices": ["Ancient maritime archaeology primarily involves studying underwater shipwrecks and ports to understand historical trade and navigation.", "Ancient maritime archaeology mainly deals with preserving modern boats to prevent decay.", "Ancient maritime archaeology is solely concerned with finding treasure from shipwrecks.", "Ancient maritime archaeology studies only the construction techniques of ancient ships."], "ans_choices_with_explanation": {"Ancient maritime archaeology primarily involves studying underwater shipwrecks and ports to understand historical trade and navigation.": "This choice accurately summarizes the main focus and methods of ancient maritime archaeology described in the paragraph.", "Ancient maritime archaeology mainly deals with preserving modern boats to prevent decay.": "This choice is incorrect because the paragraph discusses ancient shipwrecks, not preservation of modern boats.", "Ancient maritime archaeology is solely concerned with finding treasure from shipwrecks.": "This choice is incorrect as the paragraph emphasizes historical and cultural insights, not treasure hunting.", "Ancient maritime archaeology studies only the construction techniques of ancient ships.": "This choice is incorrect since the paragraph covers broader topics including trade routes and cultural exchanges, not just ship construction."}, "correct_answer": "Ancient maritime archaeology primarily involves studying underwater shipwrecks and ports to understand historical trade and navigation."}
# {"genre": "Environmental Science and Urban Ecology", "question": "Urban ecology studies the interactions between living organisms and their urban environments. A nuanced aspect is how green roofs contribute to urban biodiversity by providing habitats for insects and birds in cities. These installations mitigate heat island effects and improve air quality by filtering pollutants. While green roofs are often valued for aesthetic and environmental reasons, their role in supporting urban wildlife is increasingly recognized. Which choice best describes the main idea of the text?", "ans_choices": ["Green roofs enhance urban biodiversity by providing habitats and mitigating environmental impacts.", "Green roofs are primarily installed for aesthetic purposes in urban areas.", "Urban ecology focuses solely on the study of air quality in cities.", "Green roofs increase the financial value of buildings without ecological effects."], "ans_choices_with_explanation": {"Green roofs enhance urban biodiversity by providing habitats and mitigating environmental impacts.": "This choice accurately captures the main idea about green roofs supporting biodiversity and environmental benefits.", "Green roofs are primarily installed for aesthetic purposes in urban areas.": "This choice is tempting but unsupported as the text emphasizes ecological benefits rather than aesthetics.", "Urban ecology focuses solely on the study of air quality in cities.": "This choice is incorrect as the text discusses multiple ecological aspects, not just air quality.", "Green roofs increase the financial value of buildings without ecological effects.": "This choice is incorrect since the text highlights ecological roles, not financial impact."}, "correct_answer": "Green roofs enhance urban biodiversity by providing habitats and mitigating environmental impacts."}
# {"genre": "Astronomy", "question": "The study of pulsars, highly magnetized rotating neutron stars, has revealed valuable insights into the behavior of matter under extreme conditions. Pulsars emit beams of electromagnetic radiation observable when the beam points toward Earth, creating a lighthouse effect. Their precise rotational periods have made them useful tools for testing the laws of physics in strong gravitational fields. These observations contribute to our understanding of the universe's fundamental forces.\nWhich choice best describes the main idea of the text?", "ans_choices": ["Pulsars provide critical information for studying the behavior of matter and physics under extreme conditions.", "Pulsars are the only celestial objects that emit electromagnetic radiation.", "The text explains the history of astronomy and its key discoveries.", "The passage focuses on how pulsars are used for navigation in space travel."], "ans_choices_with_explanation": {"Pulsars provide critical information for studying the behavior of matter and physics under extreme conditions.": "This choice accurately captures the central focus on pulsars' role in advancing scientific knowledge.", "Pulsars are the only celestial objects that emit electromagnetic radiation.": "This is incorrect because other celestial objects also emit electromagnetic radiation, not just pulsars.", "The text explains the history of astronomy and its key discoveries.": "This is incorrect as the passage specifically discusses pulsars, not the history of astronomy.", "The passage focuses on how pulsars are used for navigation in space travel.": "This is incorrect because the passage does not mention space travel or navigation uses of pulsars."}, "correct_answer": "Pulsars provide critical information for studying the behavior of matter and physics under extreme conditions."}
# {"genre": "Renaissance Art Techniques", "question": "During the Renaissance, artists developed innovative techniques such as chiaroscuro, which uses strong contrasts between light and dark to achieve a sense of volume in modeling three-dimensional objects and figures. This technique was not merely decorative but played a crucial role in enhancing the emotional depth and realism of the artwork. The meticulous application of chiaroscuro allowed painters to guide viewers\u2019 attention and create dramatic effects, which fundamentally transformed the visual language of art. Which choice best describes the main idea of the text?", "ans_choices": ["Chiaroscuro was an important Renaissance technique that enhanced realism and emotional impact in paintings.", "Renaissance artists primarily focused on decorative patterns rather than emotional expression.", "Chiaroscuro was used mainly to depict landscapes in Renaissance paintings.", "Renaissance art techniques were static and lacked dramatic effects."], "ans_choices_with_explanation": {"Chiaroscuro was an important Renaissance technique that enhanced realism and emotional impact in paintings.": "This choice accurately captures the main idea about chiaroscuro's role in Renaissance art.", "Renaissance artists primarily focused on decorative patterns rather than emotional expression.": "This choice is tempting but incorrect because the passage emphasizes emotional depth, not decoration.", "Chiaroscuro was used mainly to depict landscapes in Renaissance paintings.": "Incorrect because the passage discusses chiaroscuro\u2019s use in modeling figures, not landscapes.", "Renaissance art techniques were static and lacked dramatic effects.": "Incorrect as the passage states chiaroscuro created dramatic effects and transformed art visual language."}, "correct_answer": "Chiaroscuro was an important Renaissance technique that enhanced realism and emotional impact in paintings."}
# {"genre": "Renaissance Scientific Instruments", "question": "During the Renaissance, the creation and use of scientific instruments marked a significant shift in the approach to empirical observation and measurement. Instruments such as the astrolabe and the early telescope were not only tools for navigation and astronomy but symbols of a growing emphasis on precision and experimentation. Artisans and scholars collaborated closely, blending craftsmanship with scientific inquiry. This period laid the groundwork for modern scientific methods by valuing reproducibility and careful documentation.\nWhich choice best describes the main idea of the text?", "ans_choices": ["The Renaissance period was defined by the artistic beauty of scientific instruments.", "Renaissance scientific instruments exemplified a new focus on empirical observation and collaboration between artisans and scholars.", "Scientific instruments during the Renaissance were primarily used for decorative purposes in royal courts.", "The Renaissance was a period that rejected traditional methods in favor of purely theoretical science."], "ans_choices_with_explanation": {"The Renaissance period was defined by the artistic beauty of scientific instruments.": "This choice incorrectly emphasizes aesthetics over the instruments' scientific significance.", "Renaissance scientific instruments exemplified a new focus on empirical observation and collaboration between artisans and scholars.": "This choice correctly captures the main idea of the text about the role of instruments in advancing scientific methods.", "Scientific instruments during the Renaissance were primarily used for decorative purposes in royal courts.": "This choice is clearly incorrect as the text highlights their use in navigation and astronomy, not decoration.", "The Renaissance was a period that rejected traditional methods in favor of purely theoretical science.": "This choice misrepresents the text, which emphasizes practical experimentation, not rejection of methods."}, "correct_answer": "Renaissance scientific instruments exemplified a new focus on empirical observation and collaboration between artisans and scholars."}
# {"genre": "Ancient Civilizations", "question": "The Indus Valley Civilization, one of the earliest urban cultures, developed advanced sanitation systems that were unprecedented in their time. Cities like Mohenjo-Daro featured intricate drainage and sewage systems, reflecting a high value placed on public hygiene. These innovations highlight the civilization's sophisticated urban planning and social organization, which influenced later societies. Which choice best describes the main idea of the text?", "ans_choices": ["The Indus Valley Civilization's urban planning included advanced sanitation systems, indicating a high level of social organization.", "The Indus Valley Civilization was the only ancient culture to develop urban sanitation systems.", "The Indus Valley Civilization's art and architecture were the most influential in history.", "The Indus Valley Civilization lacked any form of organized social structure."], "ans_choices_with_explanation": {"The Indus Valley Civilization's urban planning included advanced sanitation systems, indicating a high level of social organization.": "This choice accurately captures the main idea about sanitation reflecting urban planning and social order.", "The Indus Valley Civilization was the only ancient culture to develop urban sanitation systems.": "This is unsupported as the text does not claim exclusivity.", "The Indus Valley Civilization's art and architecture were the most influential in history.": "This is incorrect; the text focuses on sanitation and urban planning, not art or architecture.", "The Indus Valley Civilization lacked any form of organized social structure.": "This contradicts the text which indicates social organization through urban planning."}, "correct_answer": "The Indus Valley Civilization's urban planning included advanced sanitation systems, indicating a high level of social organization."}
# {"genre": "Architectural History", "question": "The evolution of gothic architecture in medieval Europe is often attributed to advancements in engineering, yet the nuanced role of stained glass windows in transforming interior light dynamics is less frequently discussed. These windows not only served aesthetic and religious functions but also influenced the structural design by allowing taller, thinner walls. This interplay between light, art, and engineering shaped the iconic look of gothic cathedrals. Which choice best describes the main idea of the text?", "ans_choices": ["Gothic architecture's defining features are primarily due to engineering feats rather than artistic elements.", "Stained glass windows in gothic cathedrals influenced both the aesthetic and structural design, shaping the architecture's distinctive character.", "Medieval gothic architecture was mostly focused on religious symbolism without regard to engineering challenges.", "The primary purpose of stained glass windows was to provide insulation and protect the interior from weather."], "ans_choices_with_explanation": {"Gothic architecture's defining features are primarily due to engineering feats rather than artistic elements.": "This is incorrect because the text emphasizes the combined influence of stained glass windows (artistic elements) and engineering.", "Stained glass windows in gothic cathedrals influenced both the aesthetic and structural design, shaping the architecture's distinctive character.": "This is correct as it captures the main idea that stained glass windows affected both light dynamics and structural design.", "Medieval gothic architecture was mostly focused on religious symbolism without regard to engineering challenges.": "This is incorrect because the text highlights the engineering considerations alongside artistic and religious functions.", "The primary purpose of stained glass windows was to provide insulation and protect the interior from weather.": "This is incorrect since the text does not mention insulation or weather protection as functions of stained glass windows."}, "correct_answer": "Stained glass windows in gothic cathedrals influenced both the aesthetic and structural design, shaping the architecture's distinctive character."}
# {"genre": "Renewable Energy Technology", "question": "Advancements in renewable energy technology have increasingly focused on improving energy storage solutions, a critical component for maximizing the efficiency of solar and wind power systems. Recent innovations include the development of more durable and cost-effective batteries, as well as alternative storage methods such as thermal and mechanical systems. These improvements address the intermittent nature of renewable energy sources, enabling more consistent and reliable power delivery. Which choice best describes the main idea of the text?", "ans_choices": ["The main challenge in renewable energy technology is creating better energy storage to ensure consistent power supply.", "Renewable energy technology is primarily concerned with building more solar panels and wind turbines.", "Renewable energy technology is less effective than traditional energy sources because it is too costly.", "The paragraph explains how renewable energy systems have no issues related to power delivery."], "ans_choices_with_explanation": {"The main challenge in renewable energy technology is creating better energy storage to ensure consistent power supply.": "This choice accurately captures the focus on improving energy storage to enhance renewable energy efficiency.", "Renewable energy technology is primarily concerned with building more solar panels and wind turbines.": "This choice is incorrect because the paragraph emphasizes storage solutions, not the creation of energy sources.", "Renewable energy technology is less effective than traditional energy sources because it is too costly.": "This choice is unsupported by the paragraph, which discusses advancements rather than cost comparisons.", "The paragraph explains how renewable energy systems have no issues related to power delivery.": "This choice is clearly incorrect as the text highlights challenges with intermittent power delivery."}, "correct_answer": "The main challenge in renewable energy technology is creating better energy storage to ensure consistent power supply."}
# ...
# {"genre": "Mythical Symbolism in Renaissance Art", "question": "During the Renaissance, artists frequently incorporated mythical symbols into their works to convey complex ideas about human nature, morality, and the cosmos. These symbols, drawn from classical mythology, were often adapted to fit Christian themes, creating a layered meaning that required viewers to be knowledgeable about both traditions. This blending of pagan and Christian elements served to engage viewers in a more profound reflection on the spiritual and intellectual currents of the time. Which choice best describes the main idea of the text?", "ans_choices": ["Renaissance artists used mythical symbols to communicate layered meanings blending classical and Christian traditions.", "Mythical symbols were used exclusively to depict pagan beliefs in Renaissance art.", "Renaissance art avoided using complex symbolism to make artworks more accessible to the general public.", "The primary purpose of mythical symbols in Renaissance art was decorative without deeper meaning."], "ans_choices_with_explanation": {"Renaissance artists used mythical symbols to communicate layered meanings blending classical and Christian traditions.": "This choice accurately reflects the paragraph's focus on the use of mythical symbolism to convey complex ideas during the Renaissance.", "Mythical symbols were used exclusively to depict pagan beliefs in Renaissance art.": "This is incorrect because the paragraph explains that mythical symbols were adapted to fit Christian themes, not used exclusively for pagan beliefs.", "Renaissance art avoided using complex symbolism to make artworks more accessible to the general public.": "This is incorrect as the paragraph highlights the complexity and layered meanings in the symbolism used.", "The primary purpose of mythical symbols in Renaissance art was decorative without deeper meaning.": "This is incorrect because the paragraph emphasizes that the symbols conveyed complex ideas and engaged viewers intellectually."}, "correct_answer": "Renaissance artists used mythical symbols to communicate layered meanings blending classical and Christian traditions."}
# {"genre": "Ethnomusicology of the Silk Road", "question": "The Silk Road, famous for its exchange of goods, also facilitated an intricate blend of musical traditions among the diverse cultures it connected. Ethnomusicologists study how instruments, scales, and performance styles were shared and transformed along these routes, revealing a complex network of influence and adaptation. This musical exchange helped shape regional identities and contributed to cultural continuity despite political changes. Which choice best describes the main idea of the text?", "ans_choices": ["The Silk Road was primarily a trade route for goods and had little impact on cultural practices.", "Musical traditions along the Silk Road were influenced by diverse cultures and adapted over time through exchange.", "Political changes along the Silk Road eliminated cultural continuity and musical traditions.", "Ethnomusicologists focus only on instruments and scales without considering cultural context."], "ans_choices_with_explanation": {"The Silk Road was primarily a trade route for goods and had little impact on cultural practices.": "This choice is incorrect because the paragraph emphasizes musical and cultural exchange, not just trade.", "Musical traditions along the Silk Road were influenced by diverse cultures and adapted over time through exchange.": "This choice correctly summarizes the main idea about musical exchange and cultural adaptation.", "Political changes along the Silk Road eliminated cultural continuity and musical traditions.": "This choice contradicts the paragraph, which states cultural continuity despite political changes.", "Ethnomusicologists focus only on instruments and scales without considering cultural context.": "This choice is incorrect because the paragraph highlights the study of cultural influence and identity, not just instruments."}, "correct_answer": "Musical traditions along the Silk Road were influenced by diverse cultures and adapted over time through exchange."}
# {"genre": "Victorian Era Garden Design", "question": "Victorian era garden design was characterized by an intricate blend of formal structure and ornamental variety. Gardeners of the time favored exotic plants, elaborate flower beds, and winding pathways that created a sense of discovery and visual interest. This approach reflected the Victorian fascination with nature\u2019s diversity and the desire to display wealth and taste through horticulture. Garden elements were often carefully planned to provide seasonal color changes and aesthetic harmony. Which choice best describes the main idea of the text?", "ans_choices": ["Victorian era garden design combined structured layouts with diverse plant choices to create visually engaging and seasonally dynamic spaces.", "Victorian gardens were primarily designed for agricultural productivity and food cultivation.", "Victorian garden design focused exclusively on native plants and minimal decorative elements.", "Victorian gardens were unplanned and relied on natural growth patterns rather than human design."], "ans_choices_with_explanation": {"Victorian era garden design combined structured layouts with diverse plant choices to create visually engaging and seasonally dynamic spaces.": "This choice accurately captures the blend of structure and variety emphasized in the text.", "Victorian gardens were primarily designed for agricultural productivity and food cultivation.": "The passage does not mention agricultural or food production purposes, making this unsupported.", "Victorian garden design focused exclusively on native plants and minimal decorative elements.": "The text highlights exotic plants and ornamental variety, contradicting this choice.", "Victorian gardens were unplanned and relied on natural growth patterns rather than human design.": "The passage describes careful planning and design, opposing this statement."}, "correct_answer": "Victorian era garden design combined structured layouts with diverse plant choices to create visually engaging and seasonally dynamic spaces."}
# {"genre": "Anthropology", "question": "Anthropology often explores the ways in which human societies adapt their cultural practices in response to environmental changes. One specific area of interest is the study of how indigenous groups modify their subsistence strategies when faced with climate variability. These adaptations can include shifts in hunting patterns, agricultural methods, and social organization. Such changes are critical for survival and cultural continuity in fluctuating environments. Which choice best describes the main idea of the text?", "ans_choices": ["Indigenous groups alter their subsistence strategies to adapt to environmental changes.", "Anthropology primarily studies ancient human remains to understand past cultures.", "Environmental changes have no impact on human social organization.", "Subsistence strategies remain constant despite environmental variability."], "ans_choices_with_explanation": {"Indigenous groups alter their subsistence strategies to adapt to environmental changes.": "This choice accurately captures the main idea of cultural adaptation to environmental variability.", "Anthropology primarily studies ancient human remains to understand past cultures.": "This choice is incorrect because the passage focuses on cultural adaptation, not archaeological study.", "Environmental changes have no impact on human social organization.": "This choice is clearly incorrect as the passage states social organization shifts due to environmental changes.", "Subsistence strategies remain constant despite environmental variability.": "This choice is incorrect because the passage explains that subsistence strategies change in response to environmental conditions."}, "correct_answer": "Indigenous groups alter their subsistence strategies to adapt to environmental changes."}
# {"genre": "Ancient Egyptian Art", "question": "Ancient Egyptian art is renowned for its distinctive style and symbolic meanings, particularly in funerary contexts. A nuanced aspect is the use of scale to denote importance rather than realistic proportions, where pharaohs and deities appear larger than common individuals. This visual hierarchy communicates social and religious structures within the artwork itself. The consistent use of profile views for human figures also reflects cultural conventions rather than artistic limitations. Which choice best describes the main idea of the text?", "ans_choices": ["The paragraph explains how ancient Egyptian art uses scale and perspective to convey social and religious significance.", "The paragraph focuses on the technical difficulties faced by ancient Egyptian artists in creating realistic images.", "The paragraph describes the daily life of common individuals in ancient Egypt.", "The paragraph discusses the materials used in ancient Egyptian art production."], "ans_choices_with_explanation": {"The paragraph explains how ancient Egyptian art uses scale and perspective to convey social and religious significance.": "This choice correctly captures the main idea about the use of scale and perspective to communicate hierarchy.", "The paragraph focuses on the technical difficulties faced by ancient Egyptian artists in creating realistic images.": "This is unsupported as the text states the artistic choices were cultural conventions, not technical difficulties.", "The paragraph describes the daily life of common individuals in ancient Egypt.": "This is incorrect because the text focuses on art and symbolism, not daily life.", "The paragraph discusses the materials used in ancient Egyptian art production.": "This is incorrect since the text does not mention materials at all."}, "correct_answer": "The paragraph explains how ancient Egyptian art uses scale and perspective to convey social and religious significance."}
# {"genre": "Botany", "question": "Certain species of carnivorous plants have evolved unique adaptations to thrive in nutrient-poor environments. These plants capture and digest insects using specialized structures, supplementing their nutritional intake beyond what the soil can provide. Their ability to attract prey often involves producing scents or visual lures that mimic other natural elements. This strategy allows them to survive in habitats where other plants might struggle due to limited soil fertility. Which choice best describes the main idea of the text?", "ans_choices": ["Carnivorous plants use specialized adaptations to survive in nutrient-poor environments by capturing and digesting insects.", "All plants rely solely on soil nutrients for survival without any additional adaptations.", "Carnivorous plants produce flowers primarily to attract pollinators for reproduction.", "Insects are harmed by plants in all ecosystems equally, regardless of plant type."], "ans_choices_with_explanation": {"Carnivorous plants use specialized adaptations to survive in nutrient-poor environments by capturing and digesting insects.": "This choice accurately summarizes the main idea about how carnivorous plants adapt to nutrient-poor soils.", "All plants rely solely on soil nutrients for survival without any additional adaptations.": "This is incorrect because the passage explains that carnivorous plants supplement soil nutrients by capturing insects.", "Carnivorous plants produce flowers primarily to attract pollinators for reproduction.": "This is incorrect as the passage focuses on adaptations for nutrient intake, not reproduction.", "Insects are harmed by plants in all ecosystems equally, regardless of plant type.": "This is incorrect because the passage is specific to carnivorous plants in nutrient-poor environments, not all plants or ecosystems."}, "correct_answer": "Carnivorous plants use specialized adaptations to survive in nutrient-poor environments by capturing and digesting insects."}
# {"genre": "Marine Ecology", "question": "Marine ecology explores the interactions between marine organisms and their environments, focusing on the complex relationships within ecosystems such as coral reefs. One nuanced aspect is the role of keystone species, which disproportionately influence the ecological structure and biodiversity. For example, sea otters control sea urchin populations, preventing overgrazing on kelp forests. These dynamics illustrate how individual species can shape entire habitats, affecting community stability and resilience.\nWhich choice best describes the main idea of the text?", "ans_choices": ["The text explains how marine ecosystems rely on keystone species to maintain ecological balance.", "The passage describes the physical characteristics of sea otters and their habitat preferences.", "The passage argues that coral reefs are the most important marine ecosystems.", "The text provides a detailed history of marine biology as a scientific discipline."], "ans_choices_with_explanation": {"The text explains how marine ecosystems rely on keystone species to maintain ecological balance.": "This choice correctly identifies the main idea about the importance of keystone species in marine ecology.", "The passage describes the physical characteristics of sea otters and their habitat preferences.": "This choice is incorrect because the text does not focus on sea otter biology or habitat details.", "The passage argues that coral reefs are the most important marine ecosystems.": "This choice is unsupported as the text does not claim coral reefs' primacy over other ecosystems.", "The text provides a detailed history of marine biology as a scientific discipline.": "This choice is clearly incorrect because the text discusses ecological relationships, not historical development."}, "correct_answer": "The text explains how marine ecosystems rely on keystone species to maintain ecological balance."}
# {"genre": "Neuroscience and Memory Formation", "question": "Recent studies in neuroscience have focused on the hippocampus, a brain region critical for memory formation. Researchers have discovered that the hippocampus not only stores memories but also actively reorganizes them during sleep, which enhances long-term retention. This reorganization process involves neural plasticity, allowing the brain to strengthen important memories while discarding irrelevant information. Such findings suggest that memory is not static but dynamic, continuously evolving with experience and rest. Which choice best describes the main idea of the text?", "ans_choices": ["Memory formation involves active reorganization in the hippocampus during sleep.", "The hippocampus is primarily responsible for controlling emotions.", "Memories are permanently stored in the brain without change.", "Sleep has no effect on memory retention."], "ans_choices_with_explanation": {"Memory formation involves active reorganization in the hippocampus during sleep.": "This choice accurately reflects the main idea explained in the paragraph about memory reorganization and neural plasticity.", "The hippocampus is primarily responsible for controlling emotions.": "This choice is incorrect because the paragraph focuses on memory, not emotional control.", "Memories are permanently stored in the brain without change.": "This choice is incorrect because the paragraph explains that memories are dynamic and reorganized.", "Sleep has no effect on memory retention.": "This choice is clearly incorrect as the paragraph highlights the role of sleep in enhancing memory retention."}, "correct_answer": "Memory formation involves active reorganization in the hippocampus during sleep."}

# %%
# write the questions to a Json lines file
with open("Infrence_output.jsonl", "w") as f:
    for key in para:
        print(key)
        f.write(json.dumps(para[key])+ "\n")
# Out:
# Historical Archaeology
# Marine Biology
# Neoclassical Architecture
# Renaissance Art
# Environmental Science
# Medieval Architecture
# Quantum Physics
# Ancient Pottery
# Ancient Architectural Techniques
# Ancient Architecture
# Impressionist Art
# Historical Maritime Navigation
# Astrobiology
# Medieval Manuscript Art
# Medieval Manuscript Illumination
# Astrophysics
# Ancient Maritime Archaeology
# Environmental Science and Urban Ecology
# Astronomy
# Renaissance Art Techniques
# Renaissance Scientific Instruments
# Ancient Civilizations
# Architectural History
# Renewable Energy Technology
# Cognitive Psychology
# Ethnomusicology
# History of Maritime Navigation
# Medieval Literature
# Ancient Mesopotamian Architecture
# Renewable Energy Technologies
# Historical Cartography
# Quantum Computing
# History of Scientific Instruments
# Historical Botany
# Urban Archaeology
# Bioluminescence in Deep Sea Creatures
# Historical Architecture
# Geological Formations of Desert Landscapes
# Urban Green Spaces
# Ancient Navigation Methods
# Classical Music Composition Techniques
# Renaissance Scientific Illustration
# Ancient Navigation Techniques
# Medieval Manuscripts
# Urban Sociology
# Cryptozoology
# Ancient Metallurgy
# Urban Architecture
# Architectural history
# Quantum Physics in Computing
# Historical Geography
# Classical Music Composition
# Evolution of Urban Street Art
# Urban Planning
# Marine Archaeology
# Astronomical Instrumentation
# Victorian Era Urban Planning
# Botanical Illustration
# Victorian Era Botanical Illustration
# Quantum Mechanics
# Forensic Anthropology
# Victorian Era Sanitation Systems
# 19th Century American Literature
# Insect Behavior
# History of Navigation
# Paleontology
# Renaissance Architecture
# Cognitive Neuroscience
# Astrophysics and Black Holes
# Art Conservation
# Architectural Acoustics
# Ethnobotany
# Ancient Mesopotamian Literature
# Behavioral Ecology
# Underwater Archaeology
# Ecological Impact of Urban Green Spaces
# Art History
# History of Cartography
# Neuropsychology
# Ancient Egyptian Architecture
# Medieval Manuscript Studies
# Architectural History of Gothic Cathedrals
# Impressionist Painting
# Ancient Mesopotamian Trade
# Cultural Anthropology
# Digital Archaeology
# Historical Linguistics
# Ancient Astronomy
# Mythical Symbolism in Renaissance Art
# Ethnomusicology of the Silk Road
# Victorian Era Garden Design
# Anthropology
# Ancient Egyptian Art
# Botany
# Marine Ecology
# Neuroscience and Memory Formation
