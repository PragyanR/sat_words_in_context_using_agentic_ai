# %% [markdown]
# # SAT Words in Context question generation using Strands Agentic AI framework and OpenAI model
#
# ## Overview
#
# My first [attempt](https://github.com/PragyanR/GenAI_for_SAT_Prep) to create words in context type question using Llama 3B on A100 was a bit involved from a coding perspective. With the advent of Agentic AI, I was able to generate such questions under 50 lines of code and a prompt template.
#
# Strands Agentic AI framework made it very simple to try out the use case.
#
# Check out my site if you want to try out Words in Context questions that I generated: [Acesat.ai](https://www.acesat.ai/).

# %% [markdown]
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * gpt-4.1-mini access
#
# Install the requirement packages for Strands Agent

# %%
# installing pre-requisites
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: strands-agents-tools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: aiohttp>=3.12.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (3.12.15)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.12)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.12)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.36.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.36.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.0.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: litellm<2.0.0,>=1.73.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents[litellm]->-r requirements.txt (line 3)) (1.75.8)
# Requirement already satisfied: openai<1.100.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from strands-agents[litellm]->-r requirements.txt (line 3)) (1.99.9)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp>=3.12.13->-r requirements.txt (line 4)) (1.20.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (8.2.1)
# Requirement already satisfied: httpx>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: tokenizers in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.13.3)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: six<2,>=1.15 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: anyio>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: starlette>=0.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.47.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.34.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: sniffio in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from openai<1.100.0->strands-agents[litellm]->-r requirements.txt (line 3)) (4.65.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.57b0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: packaging>=18.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: wcwidth in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: html5lib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (1.1)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (5.4.0)
# Requirement already satisfied: regex in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (2023.8.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.16.1)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.36.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.73.1->strands-agents[litellm]->-r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: webencodings in /Users/praggu/Library/Python/3.11/lib/python/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.1)
#
# [notice] A new release of pip is available: 23.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Importing dependency packages
#
# Import the dependency packages

# %%
import os
from strands import Agent, tool
from strands.models.litellm import LiteLLMModel
import json

# %% [markdown]
# ### Setting up OpenAI keys
#
# Setup the OpenAI API Keys

# %%
os.environ["OPENAI_API_KEY"] = "<Key goes here>"

# %% [markdown]
# ### Setting up custom tools
#
# I created three tools for the agent to call:
#
# first, check_word_exists, a tool for the agent to check if a word was used to create a words in context question already.
#
# second, store_paragraph, a tool for the agent to call for storing the generated paragraph.
#
# third, store_answer_choices, a tool for the agent to call for storing the answer choices and the word definitions.

# %%
# Dictionary for storing SAT inference questions (keyed by genre)
para = {}

@tool
def check_genre_exists(genre: str):
    '''
    Check if this genre or a very similar one was used already.
    Args:
        genre: SAT passage genre
    '''
    return genre in para


@tool
def store_paragraph(genre: str, paragraph: str):
    '''
    Store inference paragraph
    Args:
        genre: SAT passage genre
        paragraph: paragraph ending with "because ____"
    '''
    para[genre] = {
        "genre": genre,
        "question": paragraph,
        "ans_choices": [],
        "ans_choices_with_explanation": {},
        "correct_answer": None
    }


@tool
def store_answer_choice(choice: str, explanation: str, genre: str):
    '''
    Store answer choices and explanations
    Args:
        choice: answer choice text
        explanation: brief justification
        genre: SAT passage genre
    '''
    if choice not in para[genre]["ans_choices"]:
        para[genre]["ans_choices"].append(choice)

    para[genre]["ans_choices_with_explanation"][choice] = explanation


@tool
def set_correct_answer(choice: str, genre: str):
    '''
    Store the correct inference answer
    Args:
        choice: correct answer choice
        genre: SAT passage genre
    '''
    para[genre]["correct_answer"] = choice

# %% [markdown]
# ### LLM model
#
# Agent will leverage `gpt-4.1-mini` using LiteLLM.

# %%
model = "gpt-4.1-mini"
litellm_model = LiteLLMModel(
    model_id=model, params={"max_tokens": 32000, "temperature": 0.7}
)

# %% [markdown]
# ### Generating Words in Context questions

# %%
# Prompt template for generating words in context question
prompt = '''
You are generating authentic SAT Inference / Logical Completion questions.
You MUST use the provided tools to store and validate content.

Rules (SAT Authenticity):
- Use an academic, neutral tone.
- The conclusion must be implied, not stated.
- There must be exactly ONE logically valid completion.
- Avoid opinions, exaggeration, or unsupported assumptions.

Process:
1) Create a unique random Genre for the text. It can range from History, to science, to archertecture 
2) Use check_question_genre(Genre).
   - If it returns a genre similar to the one gernerted, generate a new genre and restart.
   - else continue
3) Choose a medium-difficulty SAT inference focus (cause–effect, implied explanation, constraint-based reasoning).
4) Write a 70–90 word paragraph that ends with an incomplete sentence introduced by “because ____”.
   - Do NOT repeat earlier information.
   - The blank must require logical inference.
5) Use store_paragraph(Genre, paragraph).

Answer Choices:
6) Generate exactly four answer choices (A–D):
   - One correct logical completion
   - One tempting but unsupported inference
   - Two clearly incorrect inferences (scope shift, reversal, or extreme claim)
7) For each answer choice, call:
   store_answer_choice(choice, explanation, question_id)
   - Explanation must be one concise sentence justifying correctness or incorrectness.
8) Use set_correct_answer(correct_choice, question_id).

Output Rules:
- Do NOT reveal reasoning steps.
- Do NOT explain unless explicitly asked.
- Ensure no more than one answer is defensible; otherwise, regenerate.
'''
# Function for generating
def generate_question(prompt):
    system_prompt = "You are a simple agent that can generate a paragraph for a given word"
    agent = Agent(
        model=litellm_model,
        system_prompt=system_prompt,
        tools=[store_paragraph, store_answer_choice, check_genre_exists,set_correct_answer],
    )
    agent(prompt)

# %%
# Specify number of questions to be generated
question_count = 50
para = {}

for i in range(question_count):
    generate_question(prompt)

# Print generated genres (one per question)
for genre in para.keys():
    print(genre)
# Out:
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# Genre: Environmental Science
#
# Recent studies have shown that urban areas with a higher density of green spaces tend to have lower average temperatures during summer months. This phenomenon is observed because ____.
#
# A) The vegetation in green spaces cools the air through transpiration.
# B) People in greener areas prefer to use air conditioning less often.
# C) Green spaces absorb more heat than urban structures, raising temperatures.
# D) Urban areas with fewer green spaces have more cloud cover, reducing temperatures.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# Marine Biology
#
# Marine biologists observed that certain coral species exhibit rapid growth rates in nutrient-rich waters, which contrasts with their slower development in nutrient-poor environments. This suggests a direct relationship between nutrient availability and coral growth patterns. However, the increased growth is often accompanied by a decrease in coral skeletal density because ____.
#
# A. the corals allocate more energy to tissue expansion rather than skeleton formation
# B. the corals are exposed to higher water temperatures, which affects their skeletons
# C. nutrient-poor environments lead to faster coral growth
# D. corals grow uniformly regardless of environmental conditions
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Ancient Architecture
#
# Paragraph: Ancient architectural structures often employed specific materials and construction techniques that have withstood the test of time. The use of local stone and precise masonry contributed to the durability of these buildings. Furthermore, the inclusion of certain design elements helped distribute weight evenly, preventing collapse. These features are significant because they ensured the structures could endure natural and human-made stresses over centuries.
#
# Answer Choices:
# A. they ensured the structures could endure natural and human-made stresses over centuries.
# B. they made the buildings aesthetically pleasing to ancient civilizations.
# C. they were built primarily to serve as religious temples with symbolic meaning.
# D. they were constructed quickly to accommodate growing urban populations.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Oceanography
#
# Paragraph:
# The study of ocean currents reveals complex interactions between water temperature, salinity, and wind patterns. These currents play a crucial role in regulating global climate by distributing heat across the planet. Scientists have observed that disruptions in these currents can lead to significant climate anomalies. The changes in the ocean's surface temperature often precede alterations in current strength because ____
#
# Answer Choices:
# A. the temperature changes influence the water density, which affects current flow
# B. the wind patterns cause the temperature to change before affecting the currents
# C. changes in current strength cause immediate shifts in salinity levels
# D. global climate anomalies are unrelated to ocean current disruptions
#
# Correct Answer:
# A. the temperature changes influence the water density, which affects current flow
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Renewable Energy Technology
#
# Paragraph:
# In recent years, the efficiency of solar panels has significantly improved due to advances in photovoltaic materials and design optimization. These improvements have made solar energy a more viable option for large-scale power generation. However, despite these technological gains, the adoption rate of solar energy remains slower than expected in some regions because ____
#
# Answer Choices:
# A. local government policies and regulations are not supportive of solar energy installations
# B. solar panels are too efficient and generate excess power
# C. solar energy is universally accepted and used everywhere
# D. people prefer to use non-renewable energy sources due to tradition
#
# Correct Answer: A
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# The discovery of a rapidly rotating neutron star emitting unusual bursts of radiation has intrigued astrophysicists. These bursts do not align with previously observed patterns, suggesting a novel mechanism at work. Researchers have noted that the star's magnetic field is exceptionally strong and erratic. This could influence the radiation emissions in ways not yet fully understood because the star's magnetic field disrupts the emission of radiation in unpredictable patterns.
#
# A. the star's magnetic field disrupts the emission of radiation in unpredictable patterns.
# B. the star's rapid rotation causes the bursts of radiation to occur in predictable intervals.
# C. the star is collapsing into a black hole, which causes the bursts of radiation.
# D. the bursts of radiation indicate the star is cooling down rapidly.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Geological Studies
#
# The formation of sedimentary rock layers is influenced by the rate at which sediments are deposited. When sediments accumulate rapidly, the layers tend to be thicker and less compacted. Conversely, slower deposition rates allow more time for compaction and cementation, resulting in denser rock layers. This process also affects the preservation of fossils within the layers because ____
#
# A. the slower deposition allows more time for mineralization, enhancing fossil preservation
# B. rapid sedimentation leads to more fossils being deposited
# C. fossils are less likely to form in sedimentary rocks
# D. denser rock layers cause fossils to decay faster
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# {
#   "genre": "Architectural History",
#   "paragraph": "During the Gothic period, architects developed flying buttresses to support taller and thinner walls, allowing for larger windows filled with stained glass. This innovation significantly changed the aesthetics and structural techniques of cathedrals. The increased height and window size could only be achieved because ____",
#   "answer_choices": [
#     {
#       "choice": "the flying buttresses transferred the weight away from the walls, providing necessary support.",
#       "explanation": "This choice correctly explains the structural role of flying buttresses enabling taller walls and larger windows."
#     },
#     {
#       "choice": "the stained glass windows were made lighter than previous windows, reducing wall weight.",
#       "explanation": "This is unsupported as stained glass size did not reduce weight sufficiently to allow taller walls alone."
#     },
#     {
#       "choice": "the walls were made shorter to accommodate the flying buttresses.",
#       "explanation": "This contradicts the paragraph which states walls were taller, making it incorrect."
#     },
#     {
#       "choice": "the flying buttresses were mainly decorative and did not affect wall height.",
#       "explanation": "This reverses the functional purpose of flying buttresses and is clearly incorrect."
#     }
#   ],
#   "correct_answer": "the flying buttresses transferred the weight away from the walls, providing necessary support."
# }
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# Genre: Archaeology
#
# Recent excavations in a Bronze Age settlement revealed a significant number of animal bones with cut marks, alongside various stone tools. However, the absence of large storage pits or granaries suggests that the inhabitants did not rely heavily on agriculture. This evidence indicates a subsistence strategy focused more on hunting and gathering rather than farming because ____.
#
# A) the site lacks features associated with crop cultivation and storage, implying a diet supplemented by wild resources.
# B) the inhabitants exclusively hunted large game for survival, avoiding any plant use.
# C) the community was advanced in agriculture but chose not to store surplus food.
# D) the settlement was a temporary camp used for religious rituals only.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Cultural Anthropology
#
# In many indigenous societies, social structures and cultural practices are deeply intertwined, influencing community roles and traditions. These societies often rely on oral histories and rituals to transmit knowledge across generations, establishing a strong sense of identity and continuity. The preservation of language and customs is crucial in maintaining these cultural frameworks because the loss of language would disrupt the transmission of cultural knowledge.
#
# Answer Choices:
# A. the loss of language would disrupt the transmission of cultural knowledge.
# B. all indigenous societies have identical social structures.
# C. oral histories are less important than written records in these societies.
# D. cultural practices are irrelevant to community roles.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Geothermal Energy
#
# Paragraph: Geothermal energy harnesses heat from beneath the Earth's surface to generate electricity and provide heating solutions. This renewable resource is considered sustainable because the Earth's internal heat is vast and continuously replenished. However, the efficiency of geothermal plants depends heavily on the geological conditions of the site. Some locations have higher heat flow, making energy extraction more viable. The economic feasibility of geothermal energy projects is limited because ____
#
# Answer Choices:
# A) the initial investment and drilling costs are high, making it less accessible for widespread use
# B) geothermal energy can only be used for electricity generation
# C) geothermal energy sources are exhaustible and will deplete quickly
# D) geothermal energy production has no environmental impact
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Astrobiology
#
# Recent missions to Mars have focused on detecting signs of past or present life by analyzing soil and rock samples for organic molecules. Despite extensive searches, no definitive evidence of life has been found. However, the presence of certain methane fluctuations in the atmosphere has intrigued scientists because ____
#
# A) These fluctuations indicate geological processes rather than biological activity.
# B) These fluctuations prove that microbial life currently exists on Mars.
# C) Methane levels on Mars have no relation to either geological or biological processes.
# D) Methane fluctuations are caused by human activity on Mars.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Ancient Civilizations
#
# Archaeologists studying the remains of an ancient city have noticed a distinct lack of large storage facilities compared to other contemporary cities. This finding suggests that the city might have had a different economic or social structure, relying less on stockpiling goods and more on immediate consumption or trade. The scarcity of such storage spaces may indicate a community that was more mobile or had a different approach to resource management because ____
#
# A) the inhabitants prioritized trade and immediate use of resources over accumulation.
# B) the city was frequently attacked, forcing residents to hide their goods elsewhere.
# C) the city was entirely abandoned shortly after its founding.
# D) the inhabitants had an advanced storage technology unseen in other cities.
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
# Generating a new genre.
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# The intricate stone carvings found on many medieval cathedrals were not merely decorative but served a functional purpose in the structure's stability. These carvings often included gargoyles which acted as water spouts, directing rainwater away from the building’s foundation. The presence of such features indicates that builders anticipated heavy rainfall and designed the cathedrals to withstand it, because ____
#
# A. the builders prioritized long-term durability in their designs.
# B. the cathedrals were primarily intended to impress visitors with elaborate art.
# C. the cathedrals were built without regard to weather conditions.
# D. the carvings weakened the structural integrity of the buildings.
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
# Generating a new genre.
# Tool #3: check_genre_exists
# Generating a new genre.
# Tool #4: check_genre_exists
# Generating a new genre.
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Genre: Cognitive Psychology
#
# Research on human memory has shown that the process of recalling a past event can sometimes alter the memory itself. This phenomenon occurs because the act of retrieval involves reactivating neural pathways, which can integrate new information or biases present at the time of recall. Consequently, memories may become less accurate with repeated recollections because the retrieval process can modify the original memory trace.
#
# Answer Choices:
# A) the retrieval process can modify the original memory trace.
# B) memories are always stored perfectly and unchanged.
# C) people consciously decide to change their memories to suit their current beliefs.
# D) memory retrieval has no effect on the accuracy of the memory over time.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Ancient Mesopotamian Architecture
#
# Paragraph: Ancient Mesopotamian architecture is notable for its use of mud bricks and ziggurats, which served both religious and administrative purposes. The construction methods reflected the available materials and environmental conditions of the region. Archaeologists have observed that the placement of these structures often aligned with cardinal directions, suggesting a cultural or religious significance. However, the specific reasons for these architectural choices remain partially speculative because ____
#
# Answer Choices:
# A) the alignment and materials were influenced by both practical considerations and symbolic meanings.
# B) the materials were selected solely for their aesthetic appeal rather than availability or function.
# C) the ziggurats were primarily built as defensive military structures to protect the city.
# D) the architectural choices were random and lacked any cultural or environmental influence.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: check_genre_exists
#
# Tool #9: store_paragraph
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: store_answer_choice
#
# Tool #13: store_answer_choice
#
# Tool #14: set_correct_answer
# Recent studies have shown that the brightness of certain stars fluctuates in a predictable pattern over time. These fluctuations are not random but follow a cycle that can be precisely measured. Scientists believe this cyclical behavior is linked to the internal processes of the stars, such as nuclear fusion rates and magnetic field changes. This pattern is significant for astronomers because it allows for more accurate predictions of stellar lifecycles.
#
# A) it allows for more accurate predictions of stellar lifecycles.
# B) it proves that all stars have the same chemical composition.
# C) it indicates that stars will eventually stop emitting light entirely.
# D) it shows that brightness changes are caused by external cosmic events only.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Geology
#
# The layering of sedimentary rocks often reveals the environmental conditions present during their formation. For example, finer grains typically settle in calmer waters, while coarser grains suggest stronger currents. Additionally, the presence of certain minerals can indicate chemical conditions such as oxygen levels. These factors together allow geologists to reconstruct past landscapes because the size and composition of sediment grains reflect the energy of the environment and chemical conditions at the time of deposition.
#
# A. the size and composition of sediment grains reflect the energy of the environment and chemical conditions at the time of deposition. (Correct: This choice correctly links sediment characteristics to environmental conditions.)
# B. geologists can predict future geological events based solely on sediment layers. (Incorrect: This is unsupported as sediment layers do not forecast future events directly.)
# C. sedimentary rocks form only in desert environments, limiting their usefulness in understanding past landscapes. (Incorrect: This is wrong as sedimentary rocks form in various environments, not just deserts.)
# D. mineral presence in rocks indicates the current climate rather than past conditions. (Incorrect: This reverses the temporal focus, making it incorrect.)
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Paleontology
#
# Fossilized footprints found in sedimentary rock layers indicate that certain prehistoric creatures traveled in groups. These footprints show consistent spacing and direction, suggesting coordinated movement rather than random wandering. The presence of multiple sets of tracks in close proximity supports the idea of social behavior among these species because ____
#
# A) they avoided predators more effectively by moving together.
# B) they were migrating to find new food sources independently.
# C) the creatures were solitary and rarely encountered each other.
# D) the footprints were made by different species that coincidentally walked the same path.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: store_paragraph
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: store_answer_choice
#
# Tool #13: set_correct_answer
# The construction of Gothic cathedrals in medieval Europe required intricate stone masonry and the use of flying buttresses, which allowed for taller and more light-filled interiors. These architectural innovations were responses to both aesthetic desires and structural challenges. The widespread adoption of these techniques transformed cathedral design across regions because the flying buttresses provided essential support, enabling higher walls and larger windows without compromising stability.
#
# A. the flying buttresses provided essential support, enabling higher walls and larger windows without compromising stability.
# B. the cathedrals were built more quickly due to the new techniques.
# C. the flying buttresses were purely decorative elements.
# D. the Gothic style was abandoned shortly after its invention.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Recent observations in astrophysics have shown that certain stars exhibit irregular fluctuations in brightness. These fluctuations do not align with previously understood patterns of stellar behavior such as pulsation or eclipsing binary systems. Scientists suggest that these irregularities may be caused by unseen companions or complex magnetic activity within the stars because ____
#
# A. the presence of unseen companions or magnetic activity explains the unusual brightness fluctuations.
# B. the stars are moving closer to Earth, causing brightness changes.
# C. all stars show irregular brightness fluctuations regularly.
# D. brightness fluctuations are due to errors in measurement instruments.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Neuroscience Advances
#
# Paragraph:
# Recent studies in neuroscience have revealed that the brain's plasticity allows it to reorganize neural pathways in response to learning and experience. This adaptability is more pronounced in younger individuals, but adults also exhibit significant capacity for neural change. Such plasticity underlies the ability to recover functions after brain injuries, but full recovery is often limited because ____
#
# Answer Choices:
# A) the extent of neural damage can restrict the brain's ability to reassign functions to undamaged areas
# B) younger brains recover faster than adult brains due to higher plasticity
# C) the brain's plasticity decreases significantly after learning stops
# D) brain injuries always result in permanent loss of function regardless of plasticity
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Neuroscience
#
# Paragraph: Recent studies in neuroscience have revealed a significant correlation between the structure of the hippocampus and memory retention capabilities. Subjects with a larger hippocampal volume tend to perform better on memory tests, suggesting a biological basis for cognitive function. However, this relationship is not absolute, as environmental factors also influence memory. The exact mechanism behind this correlation remains unclear because ____
#
# Answer Choices:
# A) the hippocampus directly controls memory retention processes.
# B) environmental factors alone determine memory retention.
# C) memory retention is unrelated to brain structure.
# D) a larger hippocampus guarantees perfect memory.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Genre: Geological Sciences
#
# Sedimentary rock layers often contain fossils that provide critical information about past environments. When geologists observe a sudden change in fossil types within adjacent layers, it often indicates a significant environmental shift. For example, the disappearance of marine fossils followed by the appearance of terrestrial plant fossils suggests a change from a marine to a terrestrial environment. This transition is important to understand because ____.
#
# A. The environment transitioned from underwater to land, affecting the types of organisms that could thrive.
# B. The fossils indicate a rapid extinction of species due to a meteor impact.
# C. The sedimentary layers must be incorrectly dated because fossils changed.
# D. Fossils in sedimentary rocks are irrelevant for understanding past environments.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Renewable Energy Technologies
#
# Solar panels have become increasingly efficient in converting sunlight into electricity, yet their effectiveness can vary significantly depending on geographic location. Regions closer to the equator receive more consistent and intense sunlight throughout the year, while those farther away experience seasonal fluctuations. Additionally, cloud cover and atmospheric conditions influence solar energy absorption. These factors contribute to disparities in energy output from solar installations because ____
#
# A) solar panels in equatorial regions generally produce more electricity than those in higher latitudes
# B) solar panels are equally efficient regardless of location
# C) solar panels produce less energy in equatorial regions due to overexposure
# D) cloud cover has no impact on solar panel efficiency
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: store_paragraph
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: set_correct_answer
# Genre: Renaissance Art
#
# During the Renaissance, artists began to experiment with perspective and naturalism, which transformed the way human figures were depicted in paintings. This shift allowed for more lifelike and three-dimensional representations. Additionally, the increased patronage from wealthy families and the Church enabled artists to explore new techniques and materials. The widespread use of oil paints further enhanced the detail and color vibrancy. These developments led to a significant evolution in artistic expression because ____.
#
# A) artists could create more realistic and emotionally engaging works.
# B) art became less popular among the general public.
# C) all Renaissance paintings were created using sculptures as models.
# D) artists stopped using religious themes entirely.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Genre: Geological Formations
#
# The intricate layering of sedimentary rocks often reveals shifts in the Earth's environmental conditions over millennia. By studying these formations, geologists can infer periods of drought, flooding, or volcanic activity. However, certain abrupt changes in the layers lack a clear external cause because ____
#
# A) They may result from sudden, localized geological events that do not leave widespread evidence.
# B) They indicate long-term climate stability that contradicts other geological evidence.
# C) They prove that sedimentary layers are entirely fabricated and unreliable.
# D) They are caused by human activity in prehistoric times.
# Tool #1: check_genre_exists
# Generating a new genre and restarting.
# Tool #2: check_genre_exists
# Generating a new genre and restarting.
# Tool #3: check_genre_exists
# Generating a new genre and restarting.
# Tool #4: check_genre_exists
# Generating a new genre and restarting.
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Genre: Crystallography
#
# Paragraph: The formation of crystals is governed by the arrangement of atoms in a repeating pattern, which dictates the crystal's shape and symmetry. Variations in temperature and pressure during formation can lead to differences in crystal size and clarity. Some crystals grow rapidly while others develop slowly over long periods. The differences in growth rates are significant because the atomic bonding strength varies in different environments, influencing how quickly atoms can align into a crystal lattice.
#
# Answer Choices:
# A. the atomic bonding strength varies in different environments, influencing how quickly atoms can align into a crystal lattice.
# B. crystals with faster growth rates always have higher clarity than slower-growing crystals.
# C. all crystals grow at the same rate regardless of external conditions.
# D. crystal size is unrelated to the conditions under which the crystal forms.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Genre: Quantum Physics
#
# Quantum entanglement allows particles to instantaneously influence each other's states regardless of the distance separating them. This phenomenon challenges classical notions of locality and causality, suggesting a deeper level of physical reality. Scientists observe that entangled particles exhibit correlated behaviors that cannot be explained by any signal traveling at or below the speed of light because ____.
#
# A. the particles must be connected through a faster-than-light communication mechanism
# B. the correlation arises without any exchange of information between particles
# C. the particles influence each other through classical electromagnetic forces
# D. the speed of light can be exceeded under certain quantum conditions
# Tool #1: check_genre_exists
# I will generate a new unique random Genre.
# Tool #2: check_genre_exists
# I will generate a new unique random Genre.
# Tool #3: check_genre_exists
# I will generate a new unique random Genre.
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Atmospheric Science
#
# Volcanic eruptions can inject large quantities of ash and sulfur dioxide into the stratosphere, affecting atmospheric conditions for extended periods. These particles can reflect sunlight away from the Earth, leading to a temporary cooling effect on global temperatures. This phenomenon is often observed after major eruptions, but the cooling effect dissipates as the particles settle out of the atmosphere. This cooling impact is significant because ____
#
# A) The ash and sulfur dioxide particles increase Earth's albedo, reflecting more sunlight back into space.
# B) Volcanic eruptions increase greenhouse gases, which trap more heat in the atmosphere.
# C) The cooling effect from volcanic eruptions permanently lowers global temperatures.
# D) Ash and sulfur dioxide particles cause an immediate and permanent increase in solar radiation reaching Earth.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Ethnomusicology studies music within its cultural context, examining how different societies use sound to convey meaning, identity, and social cohesion. Instruments, rhythms, and melodies often reflect environmental and social conditions unique to each culture. However, certain musical elements appear across diverse cultures, suggesting shared human experiences or universal patterns because these musical elements may relate to common human emotional responses or physiological constraints.
#
# A. these musical elements may relate to common human emotional responses or physiological constraints
# B. all musical traditions originate from a single ancient culture
# C. musical elements are randomly distributed and have no cultural significance
# D. these shared elements prove that culture has no impact on music
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Astronomical Physics
#
# The discovery of exoplanets in habitable zones has increased interest in the search for extraterrestrial life. Variations in stellar radiation and planetary atmospheres influence the potential for life-supporting conditions. Scientists focus on planets with stable orbits and moderate climates because ____
#
# A) These factors determine the likelihood that a planet can sustain liquid water, essential for life as we know it.
# B) Exoplanets with these characteristics are more likely to have intelligent civilizations currently existing on them.
# C) Planets with unstable orbits and extreme climates are the best candidates for finding life forms.
# D) All exoplanets discovered so far have stable orbits and moderate climates.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Cognitive Neuroscience
#
# Recent studies suggest that the brain's plasticity allows it to reorganize functions after injury. This adaptability is not uniform across all regions, as some areas recover more readily than others. The degree of plasticity also appears to correlate with age, with younger brains showing greater potential for reorganization. These findings are significant for developing rehabilitation methods because ____
#
# A. The plasticity of the brain varies by region and age, influencing recovery outcomes.
# B. Brain plasticity is the same in all individuals regardless of injury type.
# C. Younger brains have less plasticity, so they recover slower than older brains.
# D. Brain plasticity only affects motor skills, not cognitive functions.
# Tool #1: check_genre_exists
#
# Tool #2: store_paragraph
#
# Tool #3: store_answer_choice
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: set_correct_answer
# Genre: History of Astronomy
#
# During the Renaissance, advancements in telescope technology allowed astronomers to observe celestial bodies more clearly than ever before. These improved observations led to challenges against the long-held geocentric model of the universe. Notably, the detailed study of planetary motions revealed inconsistencies with the Earth-centered theory. This shift in understanding occurred because ____
#
# A. the heliocentric model better explained observed planetary motions.
# B. astronomers preferred simpler explanations without observational evidence.
# C. the Earth was proven to be flat through telescope observations.
# D. all celestial bodies stopped moving according to new observations.
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Psychology of Memory
#
# Studies indicate that memories formed during emotionally charged events tend to be more vivid and durable than those from neutral experiences because ____
#
# A. the amygdala enhances the encoding of emotional memories in the brain.
# B. people have better recall for all types of memories regardless of emotional content.
# C. memories are less accurate if they involve strong emotions.
# D. the hippocampus is not involved in memory formation at all.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Geological Science
#
# The sediment layers in the Grand Canyon show a complex history of deposition and erosion spanning millions of years. Variations in mineral composition and fossil content provide clues about ancient climates and environmental changes. However, the presence of certain igneous intrusions disrupts the continuity of these layers because ____.
#
# A) the intrusions indicate volcanic activity that occurred after the sediment layers were formed
# B) the mineral composition of the intrusions matches that of the sediment layers
# C) the sediment layers formed rapidly without any interruptions
# D) the fossils in the sediment layers were all destroyed by erosion
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
# Generating a new genre.
# Tool #3: check_genre_exists
# Generating a new genre.
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Astronomical Phenomena
#
# Astronomical observations have revealed that some stars exhibit periodic dimming, which has been interpreted as evidence of orbiting planets. However, not all dimming patterns can be explained by this phenomenon alone. Variations in a star’s brightness may also result from intrinsic stellar activity, such as sunspots or flares. Therefore, it is challenging to attribute brightness changes solely to planetary transits because ____
#
# A. the observed dimming could be caused by multiple factors, not just orbiting planets
# B. all stars with dimming patterns must have orbiting planets
# C. stars do not have any intrinsic activity that affects brightness
# D. planetary transits always cause permanent brightness changes in stars
# Tool #1: check_genre_exists
# I will generate a new genre.
# Tool #2: check_genre_exists
#
# Tool #3: store_paragraph
#
# Tool #4: store_answer_choice
#
# Tool #5: store_answer_choice
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: set_correct_answer
# Genre: Ancient Astronomy
#
# Early astronomers observed the predictable movements of celestial bodies and developed calendars based on these patterns. Their recordings were meticulous, but they lacked the tools to measure distances accurately. As a result, their models of the cosmos were geocentric, placing Earth at the center. This framework persisted for centuries because ____.
#
# A. it was consistent with everyday observations and lacked contradictory evidence at the time.
# B. early astronomers had advanced technology that proved the Earth was the center.
# C. the geocentric model was abandoned quickly after being proposed.
# D. astronomers believed the cosmos was infinite and had no center.
# Tool #1: check_genre_exists
# I will generate a different genre.
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Genre: Environmental Chemistry
#
# Researchers have observed a significant increase in the rate of chemical reactions in polluted urban waterways compared to those in rural areas. This difference is attributed to the higher concentrations of reactive pollutants found in urban environments, which interact with natural water components to accelerate reactions. The altered chemical dynamics affect the aquatic ecosystems differently than expected because ____.
#
# A. the pollutants create new compounds that disrupt the food chain balance.
# B. the pollutants decrease water temperature, which affects aquatic life.
# C. rural waterways have the same chemical reaction rates as urban ones.
# D. all pollutants are completely removed by natural processes.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: store_paragraph
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: store_answer_choice
#
# Tool #13: set_correct_answer
# Genre: Ancient Trade Routes
#
# Passage:
# Ancient trade routes connected distant civilizations, enabling the exchange of goods, ideas, and technologies. These routes often followed natural features such as rivers and mountain passes, which provided easier navigation and access to resources. The establishment and maintenance of these routes required cooperation among various groups, who benefited from mutual economic and cultural gains. The decline of certain trade routes coincided with geopolitical changes and the emergence of new powers, because ____.
#
# Answer Choices:
# A) the control of key territories shifted, disrupting the established networks.
# B) the demand for goods drastically decreased worldwide.
# C) all civilizations abandoned trade altogether.
# D) the natural features used for navigation disappeared.
#
# Correct Answer: A) the control of key territories shifted, disrupting the established networks.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: store_paragraph
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: set_correct_answer
# Genre: Astronomy and Space Exploration
#
# Paragraph: Recent observations of exoplanets have revealed a correlation between the presence of thick atmospheres and higher surface temperatures. These atmospheres, primarily composed of greenhouse gases, trap heat more effectively than thinner atmospheres. Consequently, planets with denser atmospheres exhibit significantly warmer climates compared to those with sparse or no atmospheres. This pattern helps explain why some planets maintain liquid water despite their distance from their stars because ____
#
# Answer Choices:
# A) they possess thick atmospheres that retain heat, preventing the water from freezing.
# B) they are closer to their stars, receiving more direct sunlight.
# C) they lack atmospheres, so their surfaces cool rapidly at night.
# D) they have thick atmospheres that reflect sunlight, causing colder temperatures.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: check_genre_exists
#
# Tool #9: store_paragraph
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: store_answer_choice
#
# Tool #13: store_answer_choice
#
# Tool #14: set_correct_answer
# {
#   "genre": "Quantum Mechanics",
#   "paragraph": "Quantum entanglement is a phenomenon where particles become interconnected such that the state of one instantly influences the state of another, regardless of distance. This challenges classical concepts of locality and causality. Because quantum entanglement occurs without any direct communication between particles, it suggests that information transfer in quantum systems operates under different principles than classical physics because ____",
#   "answer_choices": [
#     {
#       "choice": "quantum information can be shared instantaneously between entangled particles.",
#       "explanation": "This choice correctly infers the implication of instantaneous state influence in entanglement."
#     },
#     {
#       "choice": "classical communication methods are faster than quantum entanglement.",
#       "explanation": "This choice is tempting but unsupported as entanglement does not involve classical communication speeds."
#     },
#     {
#       "choice": "entangled particles send signals through physical media to communicate.",
#       "explanation": "This is incorrect because entanglement does not involve signal transmission through physical media."
#     },
#     {
#       "choice": "quantum entanglement disproves the existence of particles.",
#       "explanation": "This is an extreme claim that incorrectly reverses the concept of particles in quantum mechanics."
#     }
#   ],
#   "correct_answer": "quantum information can be shared instantaneously between entangled particles."
# }
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
# Generating a new genre.
# Tool #3: check_genre_exists
# Generating a new genre.
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Urban Planning
#
# Urban planners often design cities to accommodate growing populations while preserving green spaces. These plans include zoning laws that restrict certain types of construction and encourage mixed-use developments. However, when planners prioritize automobile traffic flow above pedestrian needs, urban areas may become less walkable, which can decrease community interaction because the design discourages walking and social activities, reducing opportunities for residents to meet.
#
# A. the design discourages walking and social activities, reducing opportunities for residents to meet. (Correct: This choice logically completes the paragraph by linking decreased walkability to reduced community interaction.)
# B. public transportation systems become more efficient and widely used. (Unsupported: The paragraph does not address public transportation efficiency.)
# C. commercial development increases, leading to economic growth. (Incorrect: Introduces an unrelated economic effect not implied by the paragraph.)
# D. pedestrian needs are met better than automobile needs. (Incorrect: Contradicts the paragraph's premise about prioritizing automobile traffic flow.)
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Genre: Medieval History
#
# During the medieval period, the construction of castles was not only a demonstration of power but also a strategic necessity. The location of a castle was often chosen for its natural defenses, such as hills or rivers, which could slow down or deter enemy advances. Additionally, castles were equipped with various fortifications like thick walls and moats to enhance security. Because castles were built with these defensive considerations in mind, ____
#
# A) they were difficult for invading forces to capture.
# B) they served primarily as royal residences without military functions.
# C) they were often located in lowland areas prone to flooding.
# D) they were built mainly for aesthetic purposes to display wealth.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
# Marine Biology is already used. I will generate a new genre.
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: check_genre_exists
#
# Tool #9: store_paragraph
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: store_answer_choice
#
# Tool #13: store_answer_choice
#
# Tool #14: set_correct_answer
# Genre: Linguistics
#
# Paragraph: Linguists have observed that the structure of a language can influence how its speakers perceive time and space. For example, some languages use absolute directions like north and south instead of relative terms like left and right. This suggests that language shapes cognitive processes because ____
#
# Answer choices:
# A) Language influences thought patterns by embedding spatial orientation in communication.
# B) People who speak languages with absolute directions have better navigational skills regardless of experience.
# C) Languages with absolute directions developed because humans originally lived in open plains.
# D) All languages affect cognitive processes in the same way.
#
# Correct answer: A
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: store_paragraph
#
# Tool #6: store_answer_choice
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: set_correct_answer
# Quantum computers use principles of quantum mechanics to perform certain calculations much faster than classical computers. Their ability to process complex quantum states simultaneously allows them to solve specific problems that are intractable for traditional machines. However, these systems require extremely low temperatures to maintain quantum coherence because the delicate quantum states are easily disrupted by thermal energy.
#
# A. the delicate quantum states are easily disrupted by thermal energy.
# B. quantum computers need high temperatures to function properly.
# C. classical computers operate better at low temperatures than quantum computers.
# D. quantum computers can operate in any environmental condition without performance loss.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: check_genre_exists
#
# Tool #9: check_genre_exists
#
# Tool #10: check_genre_exists
#
# Tool #11: store_paragraph
#
# Tool #12: store_answer_choice
#
# Tool #13: store_answer_choice
#
# Tool #14: store_answer_choice
#
# Tool #15: store_answer_choice
#
# Tool #16: set_correct_answer
# Genre: Botany
#
# Paragraph: In studying the growth patterns of various plant species, researchers observed that some plants developed broader leaves in shaded environments compared to those in direct sunlight. This adaptation maximizes the surface area available for photosynthesis under low-light conditions. Conversely, plants in full sun often have narrower leaves to reduce water loss through transpiration. This difference in leaf morphology is significant because ____.
#
# Answer Choices:
# A) Plants in shaded areas have broader leaves to increase light absorption for photosynthesis.
# B) Plants in full sun develop broader leaves to capture more sunlight.
# C) All plants have the same leaf shape regardless of their environment.
# D) Plants with narrower leaves always grow faster than those with broader leaves.
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: store_paragraph
#
# Tool #7: store_answer_choice
#
# Tool #8: store_answer_choice
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: set_correct_answer
# Ice core samples from polar regions have provided detailed climate records dating back hundreds of thousands of years. These records show patterns of temperature fluctuations and greenhouse gas concentrations over time. By comparing these patterns with geological events, scientists have inferred how past climates responded to natural factors. The data suggest that abrupt climate changes occurred in relatively short periods because there were sudden shifts in ocean currents that redistributed heat globally.
#
# A. there were sudden shifts in ocean currents that redistributed heat globally
# B. volcanic eruptions gradually increased atmospheric dust over millions of years
# C. human industrial activity caused the ancient climate shifts
# D. greenhouse gases had no effect on past climate changes
# Tool #1: check_genre_exists
#
# Tool #2: check_genre_exists
#
# Tool #3: check_genre_exists
#
# Tool #4: check_genre_exists
#
# Tool #5: check_genre_exists
#
# Tool #6: check_genre_exists
#
# Tool #7: check_genre_exists
#
# Tool #8: store_paragraph
#
# Tool #9: store_answer_choice
#
# Tool #10: store_answer_choice
#
# Tool #11: store_answer_choice
#
# Tool #12: store_answer_choice
#
# Tool #13: set_correct_answer
# Genre: Geological Processes
#
# Sedimentary rock formations often show distinct layering, which can be attributed to the varying conditions of sediment deposition over time. These layers differ in composition, grain size, and color, reflecting changes in environmental factors such as water flow and mineral availability. Because ____
#
# A. the environment during deposition remained constant
# B. the differences in layers indicate changes in sediment source or depositional environment
# C. sedimentary rocks are formed by volcanic activity
# D. all sedimentary layers have the same mineral composition
# Tool #1: check_genre_exists
# Generating a new genre.
# Tool #2: check_genre_exists
# Generating a new genre.
# Tool #3: check_genre_exists
# Generating a new genre.
# Tool #4: check_genre_exists
# Generating a new genre.
# Tool #5: check_genre_exists
# Generating a new genre.
# Tool #6: check_genre_exists
# Generating a new genre.
# Tool #7: check_genre_exists
# Generating a new genre.
# Tool #8: check_genre_exists
# Generating a new genre.
# Tool #9: check_genre_exists
# Generating a new genre.
# Tool #10: check_genre_exists
# Generating a new genre.
# Tool #11: check_genre_exists
#
# Tool #12: store_paragraph
#
# Tool #13: store_answer_choice
#
# Tool #14: store_answer_choice
#
# Tool #15: store_answer_choice
#
# Tool #16: store_answer_choice
#
# Tool #17: set_correct_answer
# Genre: Classical Mythology
#
# In classical mythology, many gods and heroes possess unique abilities that symbolize natural forces or human traits. These mythological figures often interact in ways that reflect the values and fears of ancient societies. The stories sometimes reveal underlying reasons for natural phenomena or moral lessons. For instance, the tale of Demeter and Persephone explains the changing seasons because ____.
#
# A) Persephone's descent to the underworld causes Demeter's grief, leading to the barren winter months.
# B) Demeter's anger results in the constant darkness of night.
# C) Persephone's return causes the sun to shine all year round.
# D) Demeter and Persephone's story explains the creation of the earth's oceans.Environmental Science
# Marine Biology
# Ancient Architecture
# Oceanography
# Renewable Energy Technology
# Astrophysics
# Geological Studies
# Architectural History
# Archaeology
# Cultural Anthropology
# Geothermal Energy
# Astrobiology
# Ancient Civilizations
# Medieval Architecture
# Cognitive Psychology
# Ancient Mesopotamian Architecture
# Astronomy
# Geology
# Paleontology
# Historical Architecture
# Neuroscience Advances
# Neuroscience
# Geological Sciences
# Renewable Energy Technologies
# Renaissance Art
# Geological Formations
# Crystallography
# Quantum Physics
# Atmospheric Science
# Ethnomusicology
# Astronomical Physics
# Cognitive Neuroscience
# History of Astronomy
# Psychology of Memory
# Geological Science
# Astronomical Phenomena
# Ancient Astronomy
# Environmental Chemistry
# Ancient Trade Routes
# Astronomy and Space Exploration
# Quantum Mechanics
# Urban Planning
# Medieval History
# Linguistics
# Quantum Computing
# Botany
# Paleoclimatology
# Geological Processes
# Classical Mythology

# %%
# Print generated genres (one per question)
for genre in para.keys():
    print(genre)
# Out:
# Environmental Science
# Marine Biology
# Ancient Architecture
# Oceanography
# Renewable Energy Technology
# Astrophysics
# Geological Studies
# Architectural History
# Archaeology
# Cultural Anthropology
# Geothermal Energy
# Astrobiology
# Ancient Civilizations
# Medieval Architecture
# Cognitive Psychology
# Ancient Mesopotamian Architecture
# Astronomy
# Geology
# Paleontology
# Historical Architecture
# Neuroscience Advances
# Neuroscience
# Geological Sciences
# Renewable Energy Technologies
# Renaissance Art
# Geological Formations
# Crystallography
# Quantum Physics
# Atmospheric Science
# Ethnomusicology
# Astronomical Physics
# Cognitive Neuroscience
# History of Astronomy
# Psychology of Memory
# Geological Science
# Astronomical Phenomena
# Ancient Astronomy
# Environmental Chemistry
# Ancient Trade Routes
# Astronomy and Space Exploration
# Quantum Mechanics
# Urban Planning
# Medieval History
# Linguistics
# Quantum Computing
# Botany
# Paleoclimatology
# Geological Processes
# Classical Mythology

# %%
for key in para:
    print(json.dumps(para[key]))
# Out:
# {"genre": "Marine Biology", "question": "Marine biologists have observed that certain coral species are more resilient to temperature changes than others. This resilience is not solely due to genetic factors but is also influenced by the coral's symbiotic relationship with algae that can adjust their photosynthetic activity. These algae provide essential nutrients to the coral, helping it survive stressful conditions. Therefore, some corals can better withstand warming oceans because ____", "ans_choices": ["the algae associated with these corals can alter their photosynthesis to support coral metabolism under heat stress.", "these corals are genetically superior in all environmental conditions.", "the corals' resilience causes the algae to improve their photosynthesis.", "all marine organisms adapt equally well to temperature changes in the ocean."], "ans_choices_with_explanation": {"the algae associated with these corals can alter their photosynthesis to support coral metabolism under heat stress.": "This directly connects the coral's resilience to the algae's adaptable photosynthesis, logically completing the inference.", "these corals are genetically superior in all environmental conditions.": "This is a tempting overgeneralization unsupported by the paragraph, which emphasizes algae influence rather than genetic superiority alone.", "the corals' resilience causes the algae to improve their photosynthesis.": "This reverses the cause-effect relationship presented in the paragraph, making it incorrect.", "all marine organisms adapt equally well to temperature changes in the ocean.": "This is an extreme claim beyond the scope of the paragraph focused on specific coral species."}, "correct_answer": null}
# {"genre": "Historical Anthropology", "question": "Archaeological evidence reveals that the early humans in this region developed complex social structures earlier than previously thought. This conclusion is supported by the discovery of communal living spaces and shared tool-making sites. These findings challenge earlier theories that isolated individuals were the primary social units because ____", "ans_choices": ["The communal living spaces indicate coordinated group activities that necessitated social organization.", "Early humans only used tools for individual tasks unrelated to social interaction.", "The discovery means that early humans had no social structures at all.", "These findings prove that early humans were fully modern in their social behavior from the start.", "A"], "ans_choices_with_explanation": {"The communal living spaces indicate coordinated group activities that necessitated social organization.": "This choice is correct because communal spaces imply coordinated social behavior.", "Early humans only used tools for individual tasks unrelated to social interaction.": "This is tempting but unsupported; tool use does not exclusively imply isolation.", "The discovery means that early humans had no social structures at all.": "This is incorrect as it contradicts the evidence of communal living spaces.", "These findings prove that early humans were fully modern in their social behavior from the start.": "This is incorrect because it overstates the evidence and timeline.", "A": "This choice is correct because communal spaces imply coordinated social behavior."}, "correct_answer": null}
# {"genre": "Renaissance Art", "question": "During the Renaissance, artists developed new techniques in perspective that allowed them to create more lifelike and three-dimensional images. This artistic innovation contributed to a greater appreciation of naturalism in painting. The shift towards realism also influenced other fields such as anatomy and architecture because ____", "ans_choices": ["these fields began incorporating detailed observations of the human body and spatial design.", "artists stopped focusing on human figures and instead painted abstract forms.", "the Renaissance period rejected classical methods in favor of entirely new artistic styles.", "architects abandoned all traditional designs to build experimental structures without regard for function."], "ans_choices_with_explanation": {"these fields began incorporating detailed observations of the human body and spatial design.": "This is correct because the paragraph implies that realism influenced detailed observation in related fields.", "artists stopped focusing on human figures and instead painted abstract forms.": "This is incorrect because the paragraph emphasizes a move toward naturalism, not abstraction.", "the Renaissance period rejected classical methods in favor of entirely new artistic styles.": "This is incorrect because the paragraph does not suggest a complete rejection of classical methods, but rather an evolution towards realism.", "architects abandoned all traditional designs to build experimental structures without regard for function.": "This is incorrect as it exaggerates the influence, ignoring the practical aspects of architecture mentioned in the paragraph."}, "correct_answer": null}
# {"genre": "Ancient Civilizations", "question": "The ancient city of Petra, carved directly into vibrant red sandstone cliffs, flourished as a vital trade hub due to its strategic location connecting various caravan routes. Archaeological findings reveal sophisticated water management systems, including dams and cisterns, that supported the city's population despite the arid environment. This level of engineering suggests that the inhabitants had advanced knowledge of hydraulics because ____", "ans_choices": ["they needed to maximize limited water resources to sustain urban life.", "they were influenced by nearby civilizations with similar water technologies.", "the city was primarily a religious center rather than a trade hub.", "the inhabitants lacked knowledge of engineering and relied on natural water sources."], "ans_choices_with_explanation": {"they needed to maximize limited water resources to sustain urban life.": "This choice logically follows from the described water management systems and arid environment.", "they were influenced by nearby civilizations with similar water technologies.": "This is plausible but not directly supported by the paragraph's information.", "the city was primarily a religious center rather than a trade hub.": "This contradicts the paragraph's emphasis on trade and engineering for population support.", "the inhabitants lacked knowledge of engineering and relied on natural water sources.": "This directly contradicts the evidence of sophisticated water management."}, "correct_answer": null}
# {"genre": "Astronomy", "question": "The discovery of exoplanets has expanded our understanding of planetary systems beyond the solar system. Many of these exoplanets orbit stars very different from the sun, with varying temperatures and compositions. The methods used to detect these planets rely heavily on observing changes in the light emitted by their stars. This reliance on stellar light variations limits detection primarily to planets that cause noticeable effects in their star's brightness because ____", "ans_choices": ["these planets must transit their stars, causing measurable dips in brightness.", "all exoplanets have atmospheres similar to Earth's.", "the number of exoplanets is far fewer than planets in our solar system.", "exoplanets are easier to detect around cooler stars than hotter stars."], "ans_choices_with_explanation": {"these planets must transit their stars, causing measurable dips in brightness.": "This correctly identifies the transit method as a detection limit based on star brightness changes.", "all exoplanets have atmospheres similar to Earth's.": "This is unsupported as detection methods do not reveal atmospheric composition universally.", "the number of exoplanets is far fewer than planets in our solar system.": "This is incorrect as it contradicts current knowledge of numerous exoplanets discovered.", "exoplanets are easier to detect around cooler stars than hotter stars.": "This is an extreme claim not directly supported by the paragraph's information."}, "correct_answer": null}
# {"genre": "Environmental Science", "question": "Wetlands serve as crucial buffers in ecosystems, absorbing excess water during heavy rains and reducing the risk of flooding downstream. They also filter pollutants, improving water quality for surrounding habitats. Because wetlands perform these functions effectively, they are often preserved and restored by environmental agencies because ____", "ans_choices": ["they help maintain ecological balance and protect human communities.", "they require more water to sustain than other ecosystems.", "they are the primary source of drinking water for cities.", "they contribute to increased flooding downstream due to water retention."], "ans_choices_with_explanation": {"they help maintain ecological balance and protect human communities.": "This is the correct inference as it logically completes the paragraph's reasoning about wetland preservation.", "they require more water to sustain than other ecosystems.": "This is a tempting but unsupported inference as the paragraph does not mention water requirements.", "they are the primary source of drinking water for cities.": "This is an incorrect inference as it shifts the scope far beyond the paragraph's focus on flood control and filtration.", "they contribute to increased flooding downstream due to water retention.": "This is an incorrect inference that reverses the paragraph's stated effect of wetlands reducing flooding."}, "correct_answer": null}
# {"genre": "Renewable Energy Technologies", "question": "Solar panels have become increasingly efficient over the past decade, yet their adoption in some regions remains limited. This is partly because these areas experience frequent cloud cover, reducing the panels' ability to generate electricity consistently. Additionally, the high initial installation cost deters many potential users. Consequently, solar energy has not replaced traditional power sources universally because ____", "ans_choices": ["solar panels depend on direct sunlight to produce energy efficiently.", "solar energy is more expensive to produce than fossil fuels everywhere.", "solar panels have been widely adopted in all regions despite weather variability.", "traditional power sources are less reliable than solar panels in cloudy areas."], "ans_choices_with_explanation": {"solar panels depend on direct sunlight to produce energy efficiently.": "Correct because solar panels' efficiency is significantly affected by sunlight availability.", "solar energy is more expensive to produce than fossil fuels everywhere.": "Incorrect because the passage only mentions high initial costs, not production costs universally.", "solar panels have been widely adopted in all regions despite weather variability.": "Incorrect because this contradicts the passage's statement about limited adoption in some regions.", "traditional power sources are less reliable than solar panels in cloudy areas.": "Incorrect because the passage implies traditional sources are still preferred where solar is less effective."}, "correct_answer": null}
# {"genre": "Geology", "question": "The layering of sedimentary rocks provides insight into the Earth's history, revealing periods of erosion and deposition. These layers can be disrupted by tectonic activity, which causes folding and faulting. Such geological disturbances complicate the interpretation of the sequence of events in a region because ____", "ans_choices": ["the original order of the layers may be altered, obscuring the timeline", "the layers become more fertile, supporting diverse plant life", "tectonic activity only occurs in volcanic regions", "folding and faulting erase all sedimentary layers entirely"], "ans_choices_with_explanation": {"the original order of the layers may be altered, obscuring the timeline": "This completion is logically valid because tectonic activity can rearrange layers, affecting chronological interpretation.", "the layers become more fertile, supporting diverse plant life": "This is unsupported because fertility and plant life are unrelated to the geological sequence interpretation.", "tectonic activity only occurs in volcanic regions": "This is incorrect as tectonic activity is not limited to volcanic regions, making this a scope error.", "folding and faulting erase all sedimentary layers entirely": "This extreme claim is false because geological disturbances do not completely erase sedimentary layers."}, "correct_answer": null}
# {"genre": "Ancient Architecture", "question": "The structural design of ancient amphitheaters often included a series of concentric rings and radial corridors that facilitated audience movement and acoustic projection. Materials used were carefully selected for durability and sound reflection. However, the absence of roofs in many amphitheaters is notable because ____", "ans_choices": ["The open-air design allowed natural ventilation and prevented sound distortion, enhancing the auditory experience.", "Roofs were avoided to reduce construction costs and time, which was a priority in ancient societies.", "Amphitheaters with roofs were common, but this design was abandoned due to frequent roof collapses.", "Roofs were not built because ancient societies did not understand the architectural principles necessary for roofing large structures."], "ans_choices_with_explanation": {"The open-air design allowed natural ventilation and prevented sound distortion, enhancing the auditory experience.": "This choice correctly infers that the open-air design serves functional acoustic and ventilation purposes, fitting the paragraph's context.", "Roofs were avoided to reduce construction costs and time, which was a priority in ancient societies.": "This choice is tempting but unsupported as the paragraph does not discuss economic factors or construction priorities.", "Amphitheaters with roofs were common, but this design was abandoned due to frequent roof collapses.": "This choice is incorrect as it contradicts the known common absence of roofs in amphitheaters and introduces an unsupported claim about roof collapses.", "Roofs were not built because ancient societies did not understand the architectural principles necessary for roofing large structures.": "This choice is clearly incorrect because it inaccurately implies a lack of architectural knowledge, which contradicts historical evidence of advanced construction techniques."}, "correct_answer": null}
# {"genre": "Renewable Energy Technology", "question": "The development of renewable energy technologies has accelerated due to increased environmental awareness and the depletion of fossil fuel reserves. Innovations in solar panel efficiency and wind turbine design have made these energy sources more viable for widespread use. However, the adoption rate varies significantly between regions because ____", "ans_choices": ["Certain regions have limited access to the necessary technology and infrastructure for renewable energy deployment.", "All regions have the same potential for renewable energy production regardless of their geographic location.", "Renewable energy is less efficient than fossil fuels in every context, so it is rarely adopted.", "Regions with abundant fossil fuel resources have universally rejected renewable energy sources."], "ans_choices_with_explanation": {"Certain regions have limited access to the necessary technology and infrastructure for renewable energy deployment.": "This choice correctly identifies a practical constraint affecting adoption rates.", "All regions have the same potential for renewable energy production regardless of their geographic location.": "This is incorrect because geographic factors heavily influence renewable energy potential.", "Renewable energy is less efficient than fossil fuels in every context, so it is rarely adopted.": "This is an extreme and incorrect claim as efficiency varies and adoption is growing.", "Regions with abundant fossil fuel resources have universally rejected renewable energy sources.": "This reverses the logical expectation and is not supported by evidence."}, "correct_answer": null}
# {"genre": "Archaeology", "question": "Archaeologists discovered a series of ancient tools in a remote cave, which showed signs of use but were made from materials not native to the region. This suggests that the people who used these tools had some form of contact or trade with distant groups. The presence of these foreign materials challenges previous assumptions about the isolation of prehistoric communities because ____", "ans_choices": ["The prehistoric community engaged in long-distance trade or exchange networks.", "The tools were used for ceremonial purposes rather than practical functions.", "The prehistoric people never left their region and invented all tools independently.", "The cave was a modern-day storage site for ancient artifacts gathered recently."], "ans_choices_with_explanation": {"The prehistoric community engaged in long-distance trade or exchange networks.": "This choice is supported by the evidence of non-native materials in the tools, indicating external contact.", "The tools were used for ceremonial purposes rather than practical functions.": "There is no direct evidence suggesting the tools were ceremonial; the materials imply trade, not function.", "The prehistoric people never left their region and invented all tools independently.": "This contradicts the evidence of non-native materials, making it an illogical conclusion.", "The cave was a modern-day storage site for ancient artifacts gathered recently.": "This reverses the timeline and is inconsistent with archaeological context indicating ancient use."}, "correct_answer": null}
# {"genre": "Geological Formations", "question": "The unique layering of sedimentary rocks in the Grand Canyon reveals a complex history of environmental changes. Some layers are rich in marine fossils, while others contain evidence of ancient riverbeds. The varying composition and thickness of these layers indicate shifts in climate, water levels, and biological activity over millions of years. The stratification pattern suggests that certain layers were deposited rapidly during periods of intense flooding because ____", "ans_choices": ["the sediment accumulation rate increased significantly due to sudden water influx.", "marine fossils were more abundant in those layers than in others.", "the climate was consistently dry during the formation of those layers.", "layers formed slowly over tens of thousands of years without interruption."], "ans_choices_with_explanation": {"the sediment accumulation rate increased significantly due to sudden water influx.": "This is the correct inference as rapid deposition logically follows from intense flooding.", "marine fossils were more abundant in those layers than in others.": "This is tempting but unsupported because fossil abundance does not directly explain rapid sediment deposition.", "the climate was consistently dry during the formation of those layers.": "Incorrect because a consistently dry climate contradicts the evidence of flooding required for rapid deposition.", "layers formed slowly over tens of thousands of years without interruption.": "Incorrect as it contradicts the implication of rapid deposition during intense flooding."}, "correct_answer": null}
# {"genre": "Cognitive Psychology", "question": "Research in cognitive psychology suggests that humans often rely on heuristics, or mental shortcuts, to make decisions quickly in complex situations. However, these heuristics can sometimes lead to systematic errors in judgment, especially when individuals face ambiguous or incomplete information. This tendency is particularly evident in confirmation bias, where people favor information that supports their existing beliefs because ____", "ans_choices": ["it reinforces their preconceptions and reduces cognitive dissonance.", "it demonstrates that people always seek out new and challenging information.", "it proves that all decisions made under ambiguity are wrong.", "it shows that people never change their beliefs regardless of evidence."], "ans_choices_with_explanation": {"it reinforces their preconceptions and reduces cognitive dissonance.": "This choice correctly identifies the psychological reason behind confirmation bias.", "it demonstrates that people always seek out new and challenging information.": "This choice is tempting but unsupported as people do not always seek challenging information.", "it proves that all decisions made under ambiguity are wrong.": "This is an extreme and incorrect generalization about decision-making.", "it shows that people never change their beliefs regardless of evidence.": "This choice is incorrect because it overstates the inflexibility of beliefs."}, "correct_answer": null}
# {"genre": "Quantum Physics", "question": "Quantum entanglement is a phenomenon where particles become interconnected such that the state of one immediately influences the state of another, regardless of distance. This challenges classical ideas of locality and causality. Experiments have demonstrated that entangled particles maintain their correlation even when separated by vast distances because ____", "ans_choices": ["the particles communicate instantaneously through a yet-undiscovered force.", "the measurement of one particle's state immediately determines the state of the other.", "particles lose their entanglement over large distances, making the correlation weak.", "entangled particles behave independently once separated, showing no correlation."], "ans_choices_with_explanation": {"the particles communicate instantaneously through a yet-undiscovered force.": "Incorrect because no instantaneous communication via a new force has been proven; quantum mechanics explains entanglement without such forces.", "the measurement of one particle's state immediately determines the state of the other.": "Correct because entanglement implies that measuring one particle's state defines the state of its entangled partner.", "particles lose their entanglement over large distances, making the correlation weak.": "Incorrect because entanglement correlations remain strong regardless of distance, not weakening over large distances.", "entangled particles behave independently once separated, showing no correlation.": "Incorrect because entangled particles exhibit correlations that defy independent behavior even when separated."}, "correct_answer": null}
# {"genre": "Ancient Maritime Navigation", "question": "Ancient sailors relied heavily on celestial bodies to guide their voyages across vast and uncharted seas. They observed the positions of stars and the moon to maintain their bearings during night travels. However, certain cloudy or stormy weather conditions often rendered these natural navigation aids useless because ____", "ans_choices": ["they could not see the stars or the moon to determine their direction.", "they could use other natural signs such as wind direction or ocean currents instead.", "ancient sailors preferred to travel only during clear weather conditions.", "they relied on advanced technological devices to navigate through storms."], "ans_choices_with_explanation": {"they could not see the stars or the moon to determine their direction.": "This is the correct completion as cloudy or stormy weather obscures celestial bodies, preventing navigation by them.", "they could use other natural signs such as wind direction or ocean currents instead.": "This is a tempting but unsupported inference as the passage does not mention alternative navigation methods.", "ancient sailors preferred to travel only during clear weather conditions.": "This is an incorrect inference as the passage does not support a preference for travel timing, just navigation challenges.", "they relied on advanced technological devices to navigate through storms.": "This is an extreme and incorrect inference as it contradicts the historical context of ancient navigation."}, "correct_answer": null}
# {"genre": "Cultural Anthropology", "question": "In many traditional societies, social roles and responsibilities are often assigned based on age and gender, serving to maintain cohesion and order within the community. These divisions allow for the efficient sharing of labor and resources, with elders typically acting as decision-makers and younger members focusing on physical tasks. However, this system sometimes limits individual autonomy because ____", "ans_choices": ["individual autonomy is subordinated to communal needs and expectations", "all members have equal access to decision-making processes", "social roles are randomly assigned without regard to age or gender", "individuals can freely choose any role they prefer in the community"], "ans_choices_with_explanation": {"individual autonomy is subordinated to communal needs and expectations": "This choice correctly identifies the logical consequence of role-based social divisions limiting autonomy.", "all members have equal access to decision-making processes": "This choice is tempting but unsupported, as the paragraph suggests elders usually make decisions.", "social roles are randomly assigned without regard to age or gender": "This is clearly incorrect as it contradicts the stated basis of role assignment.", "individuals can freely choose any role they prefer in the community": "This is clearly incorrect because the paragraph implies roles are assigned, not chosen freely."}, "correct_answer": null}
# {"genre": "Urban Ecology", "question": "Urban ecology studies the relationships between living organisms and their urban environment. One key observation is that certain bird species have adapted to city life by modifying their nesting habits. These birds tend to nest in man-made structures rather than natural settings like trees or cliffs. This shift in nesting behavior is significant because the birds find man-made structures safer from predators than natural sites.", "ans_choices": [], "ans_choices_with_explanation": {}, "correct_answer": null}
# {"genre": "Medieval Architecture", "question": "Many medieval castles were built with thick stone walls and narrow windows, features that provided defense against invaders. Additionally, the placement of castles on elevated ground made it difficult for attackers to approach unnoticed. These design choices reflect a strategic approach to security because ____", "ans_choices": ["the architects prioritized fortification to protect inhabitants from sieges.", "castle builders were primarily concerned with aesthetic appeal rather than functionality.", "the castles were designed mainly to serve as royal residences with no concern for defense.", "the castles were built to facilitate trade and open markets within city walls."], "ans_choices_with_explanation": {"the architects prioritized fortification to protect inhabitants from sieges.": "This choice correctly infers that the design features indicate a focus on defense and protection.", "castle builders were primarily concerned with aesthetic appeal rather than functionality.": "This is unsupported because the features mentioned are clearly defensive rather than decorative.", "the castles were designed mainly to serve as royal residences with no concern for defense.": "This is incorrect because the described features indicate defensive purposes, not just residential.", "the castles were built to facilitate trade and open markets within city walls.": "This is incorrect as there is no evidence that the features mentioned relate to commerce or markets."}, "correct_answer": null}
# {"genre": "Geological Processes", "question": "The stratification of rock layers in sedimentary basins often reveals the chronological order of geological events. Fossils found within these layers provide evidence of past life forms and their environments. However, radiometric dating techniques are necessary to determine the absolute ages of these layers because ____", "ans_choices": ["Radiometric dating measures the decay of radioactive isotopes to assign absolute ages to rocks.", "Fossils alone can always provide precise dates for rock layers.", "Radiometric dating can identify the type of fossils present in a rock layer.", "Sedimentary layers are always formed simultaneously, so dating is unnecessary."], "ans_choices_with_explanation": {"Radiometric dating measures the decay of radioactive isotopes to assign absolute ages to rocks.": "This choice correctly explains why radiometric dating is necessary for absolute age determination.", "Fossils alone can always provide precise dates for rock layers.": "This choice is tempting but incorrect because fossils provide relative, not absolute, dating.", "Radiometric dating can identify the type of fossils present in a rock layer.": "This choice is incorrect because radiometric dating does not identify fossil types; it dates rocks.", "Sedimentary layers are always formed simultaneously, so dating is unnecessary.": "This choice is incorrect because sedimentary layers accumulate over time, not simultaneously."}, "correct_answer": null}
# {"genre": "Medieval Literature", "question": "Medieval literature often reflects the socio-political complexities of the time, weaving themes of chivalry, religion, and feudalism into its narratives. The use of allegory and symbolism was prevalent, serving not only artistic but also educational purposes. These texts were primarily disseminated through oral traditions before the advent of widespread manuscript copying. The prominence of religious institutions in literary production influenced the moral undertones of many works because ____", "ans_choices": ["Religious institutions controlled literary output, shaping the themes and messages to align with their doctrines.", "Medieval literature was primarily written in Latin and was inaccessible to the common people.", "Medieval literature avoided religious topics to appeal to a broader audience.", "The themes in medieval literature were mostly secular and unrelated to contemporary social structures."], "ans_choices_with_explanation": {"Religious institutions controlled literary output, shaping the themes and messages to align with their doctrines.": "This choice correctly infers that religious institutions influenced the content due to their control over literary production.", "Medieval literature was primarily written in Latin and was inaccessible to the common people.": "This is a tempting inference but does not directly explain the moral undertones linked to religious institutions' influence.", "Medieval literature avoided religious topics to appeal to a broader audience.": "This is incorrect as it contradicts the known influence of religion on medieval texts.", "The themes in medieval literature were mostly secular and unrelated to contemporary social structures.": "This is an extreme claim that ignores the clear integration of social and religious themes in medieval literature."}, "correct_answer": null}
# {"genre": "Astronomical Phenomena", "question": "The brightness of a star as observed from Earth can vary significantly due to several factors. One key factor is the star's distance from Earth; closer stars generally appear brighter. Another factor is the star's intrinsic luminosity, which depends on its size and temperature. However, brightness can also be affected by interstellar dust that scatters and absorbs light, diminishing the star's apparent brightness. Therefore, the observed brightness of a star does not always directly indicate its true luminosity because ____", "ans_choices": ["the amount of interstellar dust between the star and Earth can reduce the light reaching observers.", "stars that appear dimmer are always smaller and cooler than brighter stars.", "all stars that are far away must be invisible to the naked eye.", "stars increase their brightness as they move farther from Earth."], "ans_choices_with_explanation": {"the amount of interstellar dust between the star and Earth can reduce the light reaching observers.": "This choice correctly links interstellar dust to the reduction in observed brightness, aligning with the passage.", "stars that appear dimmer are always smaller and cooler than brighter stars.": "This choice is tempting but unsupported because brightness can be affected by distance and dust, not just size and temperature.", "all stars that are far away must be invisible to the naked eye.": "This is an extreme and incorrect claim beyond the passage's scope about star visibility.", "stars increase their brightness as they move farther from Earth.": "This reverses the cause-effect relationship and contradicts the passage's information."}, "correct_answer": null}
# {"genre": "Ancient Engineering", "question": "The construction techniques used in ancient engineering projects often relied heavily on the availability of local materials, which limited the scale and design of structures. For example, the lack of advanced lifting machinery meant that builders had to use simple machines and manpower, restricting the height and weight of stone blocks that could be moved effectively. Because ____", "ans_choices": ["builders could only construct relatively low and stable structures.", "builders preferred to use imported materials for larger projects.", "ancient engineers designed skyscrapers despite material limitations.", "ancient structures were often taller than modern buildings due to advanced techniques."], "ans_choices_with_explanation": {"builders could only construct relatively low and stable structures.": "This is correct because the limitations on lifting machinery and manpower logically restrict height and weight.", "builders preferred to use imported materials for larger projects.": "Unsupported inference as the paragraph emphasizes reliance on local materials, not imports.", "ancient engineers designed skyscrapers despite material limitations.": "Clear scope shift and exaggeration, as skyscrapers are modern constructions.", "ancient structures were often taller than modern buildings due to advanced techniques.": "Reversal and extreme claim contradicting the paragraph's information."}, "correct_answer": null}
# {"genre": "Geological Studies", "question": "The sediment layers in the canyon exhibit distinct coloration patterns that correspond to varying mineral compositions. These differences suggest periods of environmental change, such as shifts in water chemistry or climate conditions. The presence of certain minerals that typically form under acidic conditions implies that the region experienced increased acidity at some point. This inference is supported by the absence of minerals that only form in alkaline environments because ____", "ans_choices": ["the sediment layers lack alkaline-formed minerals, indicating a shift in environmental pH.", "the canyon was formed by volcanic activity that altered the mineral composition.", "the region has always had a neutral pH, as evidenced by the mineral diversity.", "all minerals in the canyon formed exclusively under acidic conditions."], "ans_choices_with_explanation": {"the sediment layers lack alkaline-formed minerals, indicating a shift in environmental pH.": "This choice correctly interprets the absence of alkaline minerals as evidence of increased acidity.", "the canyon was formed by volcanic activity that altered the mineral composition.": "This is tempting but unsupported because the paragraph focuses on sediment layers and acidity, not volcanic activity.", "the region has always had a neutral pH, as evidenced by the mineral diversity.": "This is incorrect because the paragraph implies changes in acidity, contradicting a constant neutral pH.", "all minerals in the canyon formed exclusively under acidic conditions.": "This extreme claim is incorrect since the paragraph mentions minerals forming in different pH environments."}, "correct_answer": null}
# {"genre": "Astrophysics", "question": "Observations of distant galaxies reveal that many of them are moving away from us at speeds proportional to their distances, leading to the conclusion that the universe is expanding. This expansion is not due to the galaxies themselves moving through space, but rather because the fabric of space-time itself is stretching. This distinction is important because ____", "ans_choices": ["the stretching of space-time causes the increasing distances between galaxies, not their own motion through space.", "galaxies are moving away from each other because they are repelling each other with a force similar to magnetism.", "the universe is contracting instead of expanding, which contradicts the observations described.", "galaxies are stationary and the observed redshift is due to the aging of light over time.", "A"], "ans_choices_with_explanation": {"the stretching of space-time causes the increasing distances between galaxies, not their own motion through space.": "This choice correctly explains the implication that the expansion is due to space-time stretching, not galaxy movement.", "galaxies are moving away from each other because they are repelling each other with a force similar to magnetism.": "This choice is unsupported by current astrophysical understanding and is an incorrect inference.", "the universe is contracting instead of expanding, which contradicts the observations described.": "This choice reverses the fact of expansion, making it clearly incorrect.", "galaxies are stationary and the observed redshift is due to the aging of light over time.": "This choice is an extreme claim that contradicts established cosmological evidence about redshift and galaxy motion.", "A": "Choice A is the only logically valid completion because it accurately reflects the cause of the observed expansion as stretching of space-time rather than motion through space."}, "correct_answer": null}
# {"genre": "Urban Sociology", "question": "Urban sociology examines how social structures and cultural norms develop and change in city environments. One notable trend is the increase in mixed-use developments, which combine residential, commercial, and recreational spaces. These developments often encourage more pedestrian traffic and reduce reliance on cars. Consequently, neighborhoods with mixed-use developments tend to have stronger community ties because ____", "ans_choices": ["they facilitate more frequent social interactions among residents.", "they lead to higher property values and increased economic investment.", "they cause residents to spend less time in public spaces and more time indoors.", "they result in greater traffic congestion and pollution in neighborhoods."], "ans_choices_with_explanation": {"they facilitate more frequent social interactions among residents.": "This choice logically follows because mixed-use developments increase pedestrian traffic and community engagement.", "they lead to higher property values and increased economic investment.": "This is a tempting inference but focuses on economic rather than social outcomes, which is unsupported by the paragraph.", "they cause residents to spend less time in public spaces and more time indoors.": "This choice contradicts the paragraph\u2019s implication about increased pedestrian traffic and social interaction.", "they result in greater traffic congestion and pollution in neighborhoods.": "This claim reverses the effect suggested by the paragraph, which highlights reduced car reliance and pedestrian focus."}, "correct_answer": null}
# {"genre": "Glacial Geology", "question": "During the last Ice Age, massive glaciers advanced and retreated across large portions of the Northern Hemisphere. These glaciers carved distinct U-shaped valleys and deposited moraines that have been studied to understand past climate conditions. The presence of striations on exposed bedrock surfaces also indicates the direction of glacier movement. Certain areas now exhibit a pattern of soil and sediment distribution that differs markedly from surrounding regions because ____", "ans_choices": ["the glaciers deposited sediments unevenly as they melted, affecting soil composition.", "the soil in these areas was originally formed by volcanic activity unrelated to glacial processes.", "glaciers continuously deposited sediments in a uniform manner across all regions.", "the soil distribution patterns are primarily due to recent human agricultural activities."], "ans_choices_with_explanation": {"the glaciers deposited sediments unevenly as they melted, affecting soil composition.": "This choice logically completes the inference by linking glacier melting to soil and sediment patterns.", "the soil in these areas was originally formed by volcanic activity unrelated to glacial processes.": "This choice introduces an unsupported explanation unrelated to glacier influence.", "glaciers continuously deposited sediments in a uniform manner across all regions.": "This choice contradicts the observed uneven sediment pattern, making it incorrect.", "the soil distribution patterns are primarily due to recent human agricultural activities.": "This choice incorrectly attributes the pattern to modern human activity, shifting the scope from glacial effects."}, "correct_answer": null}
# {"genre": "Geological Sciences", "question": "The sediment layers found in the Grand Canyon reveal a complex history of environmental changes over millions of years. These layers vary significantly in composition and thickness, indicating shifts in climate and geological activity. The presence of certain mineral deposits suggests periodic flooding events, which reshaped the landscape and influenced erosion patterns. This sediment variation is crucial because ____", "ans_choices": ["It reflects the impact of ancient river systems on sediment deposition.", "It proves that volcanic activity was the primary force behind all sediment changes.", "It shows that human activity caused the sediment layers to form.", "It indicates that the Grand Canyon was formed in just a few decades."], "ans_choices_with_explanation": {"It reflects the impact of ancient river systems on sediment deposition.": "This choice correctly infers the role of river systems in shaping sediment layers, consistent with geological evidence.", "It proves that volcanic activity was the primary force behind all sediment changes.": "This choice is unsupported because volcanic activity is not indicated as the sole cause in the paragraph.", "It shows that human activity caused the sediment layers to form.": "This choice is invalid as human activity is not relevant to the geological timescale discussed.", "It indicates that the Grand Canyon was formed in just a few decades.": "This choice is incorrect because the paragraph discusses millions of years, not a short time span."}, "correct_answer": null}
# {"genre": "Geological Phenomena", "question": "Volcanic eruptions vary in intensity and effect depending on several factors such as magma composition, gas content, and tectonic settings. Explosive eruptions often occur when magma contains a high concentration of dissolved gases that rapidly expand as pressure decreases near the surface. These eruptions can release ash clouds that disrupt air travel and cause climate effects. In contrast, effusive eruptions produce lava flows without significant explosions because ____", "ans_choices": ["the magma has lower gas content, reducing the likelihood of violent explosions", "the lava temperature is higher, causing it to cool and solidify quickly", "tectonic plate movement is faster, increasing eruption frequency", "volcanic eruptions always produce ash clouds regardless of magma type"], "ans_choices_with_explanation": {"the magma has lower gas content, reducing the likelihood of violent explosions": "Correct because lower gas content in magma leads to less explosive eruptions, supporting effusive lava flows.", "the lava temperature is higher, causing it to cool and solidify quickly": "Incorrect because lava temperature affects flow characteristics but does not directly explain the absence of explosions.", "tectonic plate movement is faster, increasing eruption frequency": "Incorrect since eruption frequency is unrelated to whether eruptions are explosive or effusive.", "volcanic eruptions always produce ash clouds regardless of magma type": "Incorrect because not all eruptions produce ash clouds; effusive eruptions typically do not."}, "correct_answer": null}
# {"genre": "Cognitive Neuroscience", "question": "Recent studies in cognitive neuroscience suggest that the brain's capacity to multitask is limited due to neural resource allocation constraints. When individuals attempt to perform multiple demanding tasks simultaneously, performance in one or both tasks declines. This decline occurs because ____", "ans_choices": ["the brain reallocates resources to one task at the expense of the other", "people are not motivated enough to focus on both tasks at the same time", "multitasking improves overall brain efficiency by increasing neural activity", "the brain can handle unlimited tasks without performance loss"], "ans_choices_with_explanation": {"the brain reallocates resources to one task at the expense of the other": "This is a valid inference based on neural resource limitations affecting multitasking performance.", "people are not motivated enough to focus on both tasks at the same time": "Motivation is not directly addressed and is an unsupported cause in this context.", "multitasking improves overall brain efficiency by increasing neural activity": "This reverses the observed decline in performance and contradicts the premise.", "the brain can handle unlimited tasks without performance loss": "This extreme claim contradicts the stated limitation of neural resources."}, "correct_answer": null}
# {"genre": "Quantum Computing", "question": "Quantum computers leverage principles of quantum mechanics, such as superposition and entanglement, to perform calculations that would take classical computers an impractical amount of time. These properties allow quantum bits, or qubits, to represent multiple states simultaneously, vastly increasing computational power. However, maintaining qubit coherence remains a significant technical challenge because ____", "ans_choices": ["qubits are highly susceptible to environmental disturbances that cause decoherence.", "quantum computers do not require error correction mechanisms.", "qubits can maintain coherence indefinitely without external controls.", "quantum computers operate slower than classical computers in all tasks."], "ans_choices_with_explanation": {"qubits are highly susceptible to environmental disturbances that cause decoherence.": "This is correct because environmental interference disrupts qubit states, leading to loss of coherence.", "quantum computers do not require error correction mechanisms.": "This is incorrect because error correction is essential due to qubit fragility.", "qubits can maintain coherence indefinitely without external controls.": "This is incorrect since qubit coherence is temporary and needs continuous management.", "quantum computers operate slower than classical computers in all tasks.": "This reverses the known advantage of quantum computers in certain computations, so it is incorrect."}, "correct_answer": null}
# ...
# {"genre": "Classical Music", "question": "During the Baroque period, composers often used counterpoint techniques to create complex and textured musical pieces. These compositions required performers to have a high level of technical skill and precision. The widespread use of harpsichords also influenced the style and sound of the era's music. However, the popularity of Baroque music declined in the late 18th century because ____", "ans_choices": ["the emergence of the Classical style, which favored clarity and simplicity over complexity", "Baroque music was too easy for performers, leading to a lack of interest", "Baroque music was banned by governments during the late 18th century", "The invention of electronic instruments made Baroque music obsolete"], "ans_choices_with_explanation": {"the emergence of the Classical style, which favored clarity and simplicity over complexity": "This choice correctly infers the shift in musical preferences leading to Baroque music's decline.", "Baroque music was too easy for performers, leading to a lack of interest": "This is unsupported as Baroque music was known for its complexity, not ease.", "Baroque music was banned by governments during the late 18th century": "This is a clearly incorrect extreme claim with no historical basis.", "The invention of electronic instruments made Baroque music obsolete": "This is a scope shift and anachronistic, as electronic instruments came much later."}, "correct_answer": null}
# {"genre": "Urban Architecture", "question": "The design of many historic urban areas incorporates narrow streets and densely packed buildings, which often results in limited sunlight reaching lower floors. This architectural style was partly driven by the need to maximize land use within city walls during periods of rapid population growth. However, modern urban planning tends to favor wider streets and more open spaces to improve air circulation. The preference for narrow streets in older cities persists because ____", "ans_choices": ["it helped conserve space and accommodated more residents within confined city limits.", "it allowed for easier transportation of goods through the city.", "it was designed primarily to showcase wealth through grand architectural displays.", "it was intended to reduce air pollution by limiting vehicle access."], "ans_choices_with_explanation": {"it helped conserve space and accommodated more residents within confined city limits.": "This choice logically completes the paragraph by explaining the practical reason for narrow streets in historic urban areas.", "it allowed for easier transportation of goods through the city.": "This choice is tempting but unsupported, as narrow streets may hinder transportation rather than facilitate it.", "it was designed primarily to showcase wealth through grand architectural displays.": "This choice is incorrect because narrow streets do not inherently showcase wealth, contrary to the paragraph's focus on space efficiency.", "it was intended to reduce air pollution by limiting vehicle access.": "This choice is incorrect since historic urban designs predate modern concerns about vehicle emissions and air pollution."}, "correct_answer": null}
# {"genre": "Seismology", "question": "Seismologists study the vibrations that travel through the Earth caused by natural events or human activities. The speed and path of these vibrations can reveal the interior structure of the planet, including the boundaries between different layers. Recently, a new type of wave was detected, which travels more slowly than previously known waves and is absorbed in certain regions. This wave behavior can help scientists better understand the composition of the Earth's core because ____", "ans_choices": ["the new wave's absorption indicates variations in material density within the core.", "the new wave travels faster than all other known seismic waves.", "the Earth's core has no layers and is completely uniform.", "the new wave is caused by human activity rather than natural events."], "ans_choices_with_explanation": {"the new wave's absorption indicates variations in material density within the core.": "This choice correctly infers that wave absorption reveals density variations, a logical conclusion from the paragraph.", "the new wave travels faster than all other known seismic waves.": "This is unsupported since the paragraph states the new wave travels more slowly, not faster.", "the Earth's core has no layers and is completely uniform.": "This contradicts the paragraph's implication that different layers exist, making it clearly incorrect.", "the new wave is caused by human activity rather than natural events.": "The paragraph does not support this claim; it only states that waves can be caused by either source, not specifically this new wave."}, "correct_answer": null}
# {"genre": "Medieval Trade Routes", "question": "During the medieval period, certain trade routes flourished due to the demand for luxury goods such as spices and silk. These routes connected distant regions, facilitating cultural exchange and economic growth. However, some routes declined rapidly because ____", "ans_choices": ["The political instability in certain regions made travel dangerous and disrupted trade.", "The demand for luxury goods increased, leading to overcrowding on these routes.", "The invention of the steam engine replaced all medieval trade routes.", "Trade routes declined because merchants preferred to trade only within their local villages."], "ans_choices_with_explanation": {"The political instability in certain regions made travel dangerous and disrupted trade.": "This choice logically explains why some routes declined due to external factors affecting safety.", "The demand for luxury goods increased, leading to overcrowding on these routes.": "This choice is tempting but unsupported because increased demand would more likely sustain rather than decline the routes.", "The invention of the steam engine replaced all medieval trade routes.": "This is incorrect because the steam engine was invented centuries later and did not affect medieval trade routes directly.", "Trade routes declined because merchants preferred to trade only within their local villages.": "This is an extreme claim that contradicts historical evidence of long-distance trade in the medieval period."}, "correct_answer": null}
# {"genre": "Microbial Ecology", "question": "Microbial communities in extreme environments often exhibit unique metabolic pathways that allow them to survive harsh conditions such as high salinity or temperature. These adaptations are not merely survival mechanisms but also influence the broader ecosystem by cycling nutrients differently than microbes in more temperate zones. The distinctiveness of these microbial processes suggests that ecosystem functions vary significantly in extreme habitats because ____", "ans_choices": ["the metabolic pathways affect nutrient availability and recycling in ways that are not observed in moderate environments.", "microbial communities in extreme environments are less diverse than those in temperate zones.", "microbes in extreme environments do not participate in nutrient cycling.", "all microbial metabolic pathways are identical regardless of environment."], "ans_choices_with_explanation": {"the metabolic pathways affect nutrient availability and recycling in ways that are not observed in moderate environments.": "This choice logically completes the paragraph by connecting unique metabolic pathways to ecosystem function variation.", "microbial communities in extreme environments are less diverse than those in temperate zones.": "This choice is unsupported as the paragraph does not discuss diversity levels.", "microbes in extreme environments do not participate in nutrient cycling.": "This choice contradicts the paragraph which states microbes influence nutrient cycling.", "all microbial metabolic pathways are identical regardless of environment.": "This choice is incorrect as it directly opposes the paragraph's claim about unique metabolic pathways."}, "correct_answer": null}
# {"genre": "Bioluminescence in Marine Organisms", "question": "Bioluminescence in marine organisms serves various ecological functions, including predator avoidance, prey attraction, and communication. These light-producing compounds are often synthesized in specialized cells called photocytes. Interestingly, the intensity and color of bioluminescence can vary significantly among species, which suggests adaptation to different environmental niches. This variation in light emission patterns is crucial because ____", "ans_choices": ["It allows species to optimize their survival strategies according to specific environmental conditions.", "It leads to the development of new species through genetic mutation.", "It causes all marine organisms to produce the same color of light.", "It ensures that only predators can see the bioluminescent signals."], "ans_choices_with_explanation": {"It allows species to optimize their survival strategies according to specific environmental conditions.": "This choice correctly links variation in bioluminescence to ecological adaptation and survival optimization.", "It leads to the development of new species through genetic mutation.": "Unsupported inference; variation in bioluminescence alone does not directly cause speciation.", "It causes all marine organisms to produce the same color of light.": "Clearly incorrect as it contradicts the stated variation in color among species.", "It ensures that only predators can see the bioluminescent signals.": "Incorrect; bioluminescent signals serve multiple ecological functions beyond predator detection."}, "correct_answer": null}
# {"genre": "Medieval European Architecture", "question": "Medieval European cathedrals often feature flying buttresses, which are external supports that counteract the lateral forces pushing a wall outward. This architectural innovation allowed builders to construct higher walls and larger windows than previously possible. Consequently, these structures could admit more natural light despite their massive stone construction because ____", "ans_choices": ["the flying buttresses redistributed the structural forces to support the taller walls.", "the larger windows were purely decorative and did not affect the structural integrity.", "the walls were made thinner to compensate for the weight of the windows.", "the cathedrals used steel reinforcements to support the windows.", "A"], "ans_choices_with_explanation": {"the flying buttresses redistributed the structural forces to support the taller walls.": "This choice correctly explains the structural function of flying buttresses allowing for higher walls.", "the larger windows were purely decorative and did not affect the structural integrity.": "This is unsupported because larger windows required structural support, not just decoration.", "the walls were made thinner to compensate for the weight of the windows.": "This is incorrect because the walls were not made thinner; buttresses supported the walls to remain tall and strong.", "the cathedrals used steel reinforcements to support the windows.": "This is incorrect as steel reinforcements were not used in medieval architecture.", "A": "This choice correctly explains the structural function of flying buttresses allowing for higher walls."}, "correct_answer": null}
# {"genre": "Mythological Studies", "question": "Mythological stories often reflect the values and beliefs of the culture from which they originate. These narratives typically contain symbols and motifs that convey moral lessons or explain natural phenomena. The consistent recurrence of certain themes across different cultures suggests a shared human experience or psychological pattern. However, the variations in these stories highlight unique cultural priorities and historical contexts because ____", "ans_choices": ["Each culture adapts common mythological themes to address its specific societal needs and historical events.", "Mythological stories are entirely fictional and have no basis in cultural history or psychology.", "All mythological stories must originate from a single ancient source, despite cultural differences.", "Variations in myths occur because they are rewritten as modern entertainment rather than cultural artifacts.", "A"], "ans_choices_with_explanation": {"Each culture adapts common mythological themes to address its specific societal needs and historical events.": "This choice logically completes the paragraph by explaining the reason for variations in mythological stories.", "Mythological stories are entirely fictional and have no basis in cultural history or psychology.": "This choice is incorrect because the paragraph emphasizes the cultural and psychological significance of myths, not their fictional nature.", "All mythological stories must originate from a single ancient source, despite cultural differences.": "This choice is incorrect as it contradicts the paragraph's point about variations reflecting unique cultural contexts.", "Variations in myths occur because they are rewritten as modern entertainment rather than cultural artifacts.": "This choice is incorrect because it shifts the scope from cultural and historical reasons to modern entertainment, which is not supported by the paragraph.", "A": "This is the correct answer because it logically explains the variations in mythological stories as adaptations to societal needs and historical contexts."}, "correct_answer": null}
# {"genre": "Ornithology", "question": "Ornithologists have observed that certain migratory bird species tend to alter their routes slightly each year. This behavior appears to correspond with changes in climate patterns along their traditional paths. Birds seem to avoid areas that have become warmer or drier than usual, possibly to find more favorable feeding and nesting conditions. This adjustment in migration routes suggests that these species are responsive to environmental changes because ____", "ans_choices": ["the birds are adapting to optimize their survival by seeking better habitats.", "the birds have developed a permanent new migration route due to genetic mutation.", "the birds migrate randomly each year without regard to environmental conditions.", "the birds stop migrating altogether because their habitat is destroyed."], "ans_choices_with_explanation": {"the birds are adapting to optimize their survival by seeking better habitats.": "This choice accurately infers that the birds' route changes are an adaptive response to environmental changes for survival.", "the birds have developed a permanent new migration route due to genetic mutation.": "This choice is unsupported as the paragraph implies temporary adjustments, not permanent genetic changes.", "the birds migrate randomly each year without regard to environmental conditions.": "This is a clearly incorrect inference that contradicts the paragraph's observation of route changes linked to climate.", "the birds stop migrating altogether because their habitat is destroyed.": "This extreme claim is unsupported as the paragraph only discusses route changes, not cessation of migration."}, "correct_answer": null}

# %%
# write the questions to a Json lines file
with open("Main_Idea_output.jsonl", "w") as f:
    for key in para:
        print(key)
        f.write(json.dumps(para[key])+ "\n")
# Out:
# Environmental Science
# Marine Biology
# Ancient Architecture
# Oceanography
# Renewable Energy Technology
# Astrophysics
# Geological Studies
# Architectural History
# Archaeology
# Cultural Anthropology
# Geothermal Energy
# Astrobiology
# Ancient Civilizations
# Medieval Architecture
# Cognitive Psychology
# Ancient Mesopotamian Architecture
# Astronomy
# Geology
# Paleontology
# Historical Architecture
# Neuroscience Advances
# Neuroscience
# Geological Sciences
# Renewable Energy Technologies
# Renaissance Art
# Geological Formations
# Crystallography
# Quantum Physics
# Atmospheric Science
# Ethnomusicology
# Astronomical Physics
# Cognitive Neuroscience
# History of Astronomy
# Psychology of Memory
# Geological Science
# Astronomical Phenomena
# Ancient Astronomy
# Environmental Chemistry
# Ancient Trade Routes
# Astronomy and Space Exploration
# Quantum Mechanics
# Urban Planning
# Medieval History
# Linguistics
# Quantum Computing
# Botany
# Paleoclimatology
# Geological Processes
# Classical Mythology
